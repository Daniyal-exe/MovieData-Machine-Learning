# %%
import requests
import pandas as pd
import time

api_key = "my-api-key"  # hidden for privacy

# Get genre name mapping from TMDb
def get_genre_mapping(api_key):
    print("Fetching genre mapping...")
    url = f"https://api.themoviedb.org/3/genre/movie/list?api_key={api_key}&language=en-US"
    response = requests.get(url)
    if response.status_code != 200:
        print("❌ Failed to fetch genre list.")
        print(response.text)
        return {}
    data = response.json()
    genre_map = {genre["id"]: genre["name"] for genre in data["genres"]}
    print("✅ Genre mapping fetched successfully.\n")
    return genre_map

# Main function to fetch movies
def fetch_movies(api_key, pages=480):
    base_url = "https://api.themoviedb.org/3/discover/movie"
    all_movies = []
    genre_dict = get_genre_mapping(api_key)

    for page in range(1, pages + 1):
        print(f"🔄 Fetching page {page}...")

        params = {
            "api_key": api_key,
            "language": "en-US",
            "sort_by": "popularity.desc",
            "page": page
        }

        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
        except Exception as e:
            print(f"❌ Error fetching page {page}: {e}")
            continue

        data = response.json()

        if "results" not in data:
            print(f"⚠️ Unexpected response structure on page {page}")
            print(data)
            break

        for movie in data["results"]:
            genre_names = [genre_dict.get(gid, "Unknown") for gid in movie.get("genre_ids", [])]
            genre_str = ", ".join(genre_names)

            all_movies.append([
                movie.get("title"),
                movie.get("release_date"),
                movie.get("vote_average"),
                movie.get("vote_count"),
                movie.get("original_language"),
                movie.get("overview"),
                movie.get("popularity"),
                genre_str
            ])

        print(f"✅ Page {page} scraped. Total movies so far: {len(all_movies)}\n")
        time.sleep(0.5)  # Respect rate limits

    # Save to CSV
    df = pd.DataFrame(all_movies, columns=[
        "Title", "Release Date", "Rating", "Vote Count",
        "Language", "Overview", "Popularity", "Genres"
    ])
    df.to_csv("tmdb_movies.csv", index=False)
    print(f"📁 Done! Saved {len(df)} movies to 'tmdb_movies_with_genres.csv'.")

# 🔁 Run this to test (start with a few pages only)
fetch_movies(api_key, pages=480)
# Out:
# Fetching genre mapping...
# ✅ Genre mapping fetched successfully.
#
# 🔄 Fetching page 1...
# ✅ Page 1 scraped. Total movies so far: 20
#
# 🔄 Fetching page 2...
# ✅ Page 2 scraped. Total movies so far: 40
#
# 🔄 Fetching page 3...
# ✅ Page 3 scraped. Total movies so far: 60
#
# 🔄 Fetching page 4...
# ✅ Page 4 scraped. Total movies so far: 80
#
# 🔄 Fetching page 5...
# ✅ Page 5 scraped. Total movies so far: 100
#
# 🔄 Fetching page 6...
# ✅ Page 6 scraped. Total movies so far: 120
#
# 🔄 Fetching page 7...
# ✅ Page 7 scraped. Total movies so far: 140
#
# 🔄 Fetching page 8...
# ✅ Page 8 scraped. Total movies so far: 160
#
# 🔄 Fetching page 9...
# ✅ Page 9 scraped. Total movies so far: 180
#
# 🔄 Fetching page 10...
# ✅ Page 10 scraped. Total movies so far: 200
#
# 🔄 Fetching page 11...
# ✅ Page 11 scraped. Total movies so far: 220
#
# 🔄 Fetching page 12...
# ✅ Page 12 scraped. Total movies so far: 240
#
# 🔄 Fetching page 13...
# ✅ Page 13 scraped. Total movies so far: 260
#
# 🔄 Fetching page 14...
# ✅ Page 14 scraped. Total movies so far: 280
#
# 🔄 Fetching page 15...
# ✅ Page 15 scraped. Total movies so far: 300
#
# 🔄 Fetching page 16...
# ✅ Page 16 scraped. Total movies so far: 320
#
# 🔄 Fetching page 17...
# ✅ Page 17 scraped. Total movies so far: 340
#
# 🔄 Fetching page 18...
# ✅ Page 18 scraped. Total movies so far: 360
#
# 🔄 Fetching page 19...
# ✅ Page 19 scraped. Total movies so far: 380
#
# 🔄 Fetching page 20...
# ✅ Page 20 scraped. Total movies so far: 400
#
# 🔄 Fetching page 21...
# ✅ Page 21 scraped. Total movies so far: 420
#
# 🔄 Fetching page 22...
# ✅ Page 22 scraped. Total movies so far: 440
#
# 🔄 Fetching page 23...
# ✅ Page 23 scraped. Total movies so far: 460
#
# 🔄 Fetching page 24...
# ✅ Page 24 scraped. Total movies so far: 480
#
# 🔄 Fetching page 25...
# ✅ Page 25 scraped. Total movies so far: 500
#
# 🔄 Fetching page 26...
# ✅ Page 26 scraped. Total movies so far: 520
#
# 🔄 Fetching page 27...
# ✅ Page 27 scraped. Total movies so far: 540
#
# 🔄 Fetching page 28...
# ✅ Page 28 scraped. Total movies so far: 560
#
# 🔄 Fetching page 29...
# ✅ Page 29 scraped. Total movies so far: 580
#
# 🔄 Fetching page 30...
# ✅ Page 30 scraped. Total movies so far: 600
#
# 🔄 Fetching page 31...
# ✅ Page 31 scraped. Total movies so far: 620
#
# 🔄 Fetching page 32...
# ✅ Page 32 scraped. Total movies so far: 640
#
# 🔄 Fetching page 33...
# ✅ Page 33 scraped. Total movies so far: 660
#
# 🔄 Fetching page 34...
# ✅ Page 34 scraped. Total movies so far: 680
#
# 🔄 Fetching page 35...
# ✅ Page 35 scraped. Total movies so far: 700
#
# 🔄 Fetching page 36...
# ✅ Page 36 scraped. Total movies so far: 720
#
# 🔄 Fetching page 37...
# ✅ Page 37 scraped. Total movies so far: 740
#
# 🔄 Fetching page 38...
# ✅ Page 38 scraped. Total movies so far: 760
#
# 🔄 Fetching page 39...
# ✅ Page 39 scraped. Total movies so far: 780
#
# 🔄 Fetching page 40...
# ✅ Page 40 scraped. Total movies so far: 800
#
# 🔄 Fetching page 41...
# ✅ Page 41 scraped. Total movies so far: 820
#
# 🔄 Fetching page 42...
# ✅ Page 42 scraped. Total movies so far: 840
#
# 🔄 Fetching page 43...
# ✅ Page 43 scraped. Total movies so far: 860
#
# 🔄 Fetching page 44...
# ✅ Page 44 scraped. Total movies so far: 880
#
# 🔄 Fetching page 45...
# ✅ Page 45 scraped. Total movies so far: 900
#
# 🔄 Fetching page 46...
# ✅ Page 46 scraped. Total movies so far: 920
#
# 🔄 Fetching page 47...
# ✅ Page 47 scraped. Total movies so far: 940
#
# 🔄 Fetching page 48...
# ✅ Page 48 scraped. Total movies so far: 960
#
# 🔄 Fetching page 49...
# ✅ Page 49 scraped. Total movies so far: 980
#
# 🔄 Fetching page 50...
# ✅ Page 50 scraped. Total movies so far: 1000
#
# 🔄 Fetching page 51...
# ✅ Page 51 scraped. Total movies so far: 1020
#
# 🔄 Fetching page 52...
# ✅ Page 52 scraped. Total movies so far: 1040
#
# 🔄 Fetching page 53...
# ✅ Page 53 scraped. Total movies so far: 1060
#
# 🔄 Fetching page 54...
# ✅ Page 54 scraped. Total movies so far: 1080
#
# 🔄 Fetching page 55...
# ✅ Page 55 scraped. Total movies so far: 1100
#
# 🔄 Fetching page 56...
# ✅ Page 56 scraped. Total movies so far: 1120
#
# 🔄 Fetching page 57...
# ✅ Page 57 scraped. Total movies so far: 1140
#
# 🔄 Fetching page 58...
# ✅ Page 58 scraped. Total movies so far: 1160
#
# 🔄 Fetching page 59...
# ✅ Page 59 scraped. Total movies so far: 1180
#
# 🔄 Fetching page 60...
# ✅ Page 60 scraped. Total movies so far: 1200
#
# 🔄 Fetching page 61...
# ✅ Page 61 scraped. Total movies so far: 1220
#
# 🔄 Fetching page 62...
# ✅ Page 62 scraped. Total movies so far: 1240
#
# 🔄 Fetching page 63...
# ✅ Page 63 scraped. Total movies so far: 1260
#
# 🔄 Fetching page 64...
# ✅ Page 64 scraped. Total movies so far: 1280
#
# 🔄 Fetching page 65...
# ✅ Page 65 scraped. Total movies so far: 1300
#
# 🔄 Fetching page 66...
# ✅ Page 66 scraped. Total movies so far: 1320
#
# 🔄 Fetching page 67...
# ✅ Page 67 scraped. Total movies so far: 1340
#
# 🔄 Fetching page 68...
# ✅ Page 68 scraped. Total movies so far: 1360
#
# 🔄 Fetching page 69...
# ✅ Page 69 scraped. Total movies so far: 1380
#
# 🔄 Fetching page 70...
# ✅ Page 70 scraped. Total movies so far: 1400
#
# 🔄 Fetching page 71...
# ✅ Page 71 scraped. Total movies so far: 1420
#
# 🔄 Fetching page 72...
# ✅ Page 72 scraped. Total movies so far: 1440
#
# 🔄 Fetching page 73...
# ✅ Page 73 scraped. Total movies so far: 1460
#
# 🔄 Fetching page 74...
# ✅ Page 74 scraped. Total movies so far: 1480
#
# 🔄 Fetching page 75...
# ✅ Page 75 scraped. Total movies so far: 1500
#
# 🔄 Fetching page 76...
# ✅ Page 76 scraped. Total movies so far: 1520
#
# 🔄 Fetching page 77...
# ✅ Page 77 scraped. Total movies so far: 1540
#
# 🔄 Fetching page 78...
# ✅ Page 78 scraped. Total movies so far: 1560
#
# 🔄 Fetching page 79...
# ✅ Page 79 scraped. Total movies so far: 1580
#
# 🔄 Fetching page 80...
# ✅ Page 80 scraped. Total movies so far: 1600
#
# 🔄 Fetching page 81...
# ✅ Page 81 scraped. Total movies so far: 1620
#
# 🔄 Fetching page 82...
# ✅ Page 82 scraped. Total movies so far: 1640
#
# 🔄 Fetching page 83...
# ✅ Page 83 scraped. Total movies so far: 1660
#
# 🔄 Fetching page 84...
# ✅ Page 84 scraped. Total movies so far: 1680
#
# 🔄 Fetching page 85...
# ✅ Page 85 scraped. Total movies so far: 1700
#
# 🔄 Fetching page 86...
# ✅ Page 86 scraped. Total movies so far: 1720
#
# 🔄 Fetching page 87...
# ✅ Page 87 scraped. Total movies so far: 1740
#
# 🔄 Fetching page 88...
# ✅ Page 88 scraped. Total movies so far: 1760
#
# 🔄 Fetching page 89...
# ✅ Page 89 scraped. Total movies so far: 1780
#
# 🔄 Fetching page 90...
# ✅ Page 90 scraped. Total movies so far: 1800
#
# 🔄 Fetching page 91...
# ✅ Page 91 scraped. Total movies so far: 1820
#
# 🔄 Fetching page 92...
# ✅ Page 92 scraped. Total movies so far: 1840
#
# 🔄 Fetching page 93...
# ✅ Page 93 scraped. Total movies so far: 1860
#
# 🔄 Fetching page 94...
# ✅ Page 94 scraped. Total movies so far: 1880
#
# 🔄 Fetching page 95...
# ✅ Page 95 scraped. Total movies so far: 1900
#
# 🔄 Fetching page 96...
# ✅ Page 96 scraped. Total movies so far: 1920
#
# 🔄 Fetching page 97...
# ✅ Page 97 scraped. Total movies so far: 1940
#
# 🔄 Fetching page 98...
# ✅ Page 98 scraped. Total movies so far: 1960
#
# 🔄 Fetching page 99...
# ✅ Page 99 scraped. Total movies so far: 1980
#
# 🔄 Fetching page 100...
# ✅ Page 100 scraped. Total movies so far: 2000
#
# 🔄 Fetching page 101...
# ✅ Page 101 scraped. Total movies so far: 2020
#
# 🔄 Fetching page 102...
# ✅ Page 102 scraped. Total movies so far: 2040
#
# 🔄 Fetching page 103...
# ✅ Page 103 scraped. Total movies so far: 2060
#
# 🔄 Fetching page 104...
# ✅ Page 104 scraped. Total movies so far: 2080
#
# 🔄 Fetching page 105...
# ✅ Page 105 scraped. Total movies so far: 2100
#
# 🔄 Fetching page 106...
# ✅ Page 106 scraped. Total movies so far: 2120
#
# 🔄 Fetching page 107...
# ✅ Page 107 scraped. Total movies so far: 2140
#
# 🔄 Fetching page 108...
# ✅ Page 108 scraped. Total movies so far: 2160
#
# 🔄 Fetching page 109...
# ✅ Page 109 scraped. Total movies so far: 2180
#
# 🔄 Fetching page 110...
# ✅ Page 110 scraped. Total movies so far: 2200
#
# 🔄 Fetching page 111...
# ✅ Page 111 scraped. Total movies so far: 2220
#
# 🔄 Fetching page 112...
# ✅ Page 112 scraped. Total movies so far: 2240
#
# 🔄 Fetching page 113...
# ✅ Page 113 scraped. Total movies so far: 2260
#
# 🔄 Fetching page 114...
# ✅ Page 114 scraped. Total movies so far: 2280
#
# 🔄 Fetching page 115...
# ✅ Page 115 scraped. Total movies so far: 2300
#
# 🔄 Fetching page 116...
# ✅ Page 116 scraped. Total movies so far: 2320
#
# 🔄 Fetching page 117...
# ✅ Page 117 scraped. Total movies so far: 2340
#
# 🔄 Fetching page 118...
# ✅ Page 118 scraped. Total movies so far: 2360
#
# 🔄 Fetching page 119...
# ✅ Page 119 scraped. Total movies so far: 2380
#
# 🔄 Fetching page 120...
# ✅ Page 120 scraped. Total movies so far: 2400
#
# 🔄 Fetching page 121...
# ✅ Page 121 scraped. Total movies so far: 2420
#
# 🔄 Fetching page 122...
# ✅ Page 122 scraped. Total movies so far: 2440
#
# 🔄 Fetching page 123...
# ✅ Page 123 scraped. Total movies so far: 2460
#
# 🔄 Fetching page 124...
# ✅ Page 124 scraped. Total movies so far: 2480
#
# 🔄 Fetching page 125...
# ✅ Page 125 scraped. Total movies so far: 2500
#
# 🔄 Fetching page 126...
# ✅ Page 126 scraped. Total movies so far: 2520
#
# 🔄 Fetching page 127...
# ✅ Page 127 scraped. Total movies so far: 2540
#
# 🔄 Fetching page 128...
# ✅ Page 128 scraped. Total movies so far: 2560
#
# 🔄 Fetching page 129...
# ✅ Page 129 scraped. Total movies so far: 2580
#
# 🔄 Fetching page 130...
# ✅ Page 130 scraped. Total movies so far: 2600
#
# 🔄 Fetching page 131...
# ✅ Page 131 scraped. Total movies so far: 2620
#
# 🔄 Fetching page 132...
# ✅ Page 132 scraped. Total movies so far: 2640
#
# 🔄 Fetching page 133...
# ✅ Page 133 scraped. Total movies so far: 2660
#
# 🔄 Fetching page 134...
# ✅ Page 134 scraped. Total movies so far: 2680
#
# 🔄 Fetching page 135...
# ✅ Page 135 scraped. Total movies so far: 2700
#
# 🔄 Fetching page 136...
# ✅ Page 136 scraped. Total movies so far: 2720
#
# 🔄 Fetching page 137...
# ✅ Page 137 scraped. Total movies so far: 2740
#
# 🔄 Fetching page 138...
# ✅ Page 138 scraped. Total movies so far: 2760
#
# 🔄 Fetching page 139...
# ✅ Page 139 scraped. Total movies so far: 2780
#
# 🔄 Fetching page 140...
# ✅ Page 140 scraped. Total movies so far: 2800
#
# 🔄 Fetching page 141...
# ✅ Page 141 scraped. Total movies so far: 2820
#
# 🔄 Fetching page 142...
# ✅ Page 142 scraped. Total movies so far: 2840
#
# 🔄 Fetching page 143...
# ✅ Page 143 scraped. Total movies so far: 2860
#
# 🔄 Fetching page 144...
# ✅ Page 144 scraped. Total movies so far: 2880
#
# 🔄 Fetching page 145...
# ✅ Page 145 scraped. Total movies so far: 2900
#
# 🔄 Fetching page 146...
# ✅ Page 146 scraped. Total movies so far: 2920
#
# 🔄 Fetching page 147...
# ✅ Page 147 scraped. Total movies so far: 2940
#
# 🔄 Fetching page 148...
# ✅ Page 148 scraped. Total movies so far: 2960
#
# 🔄 Fetching page 149...
# ✅ Page 149 scraped. Total movies so far: 2980
#
# 🔄 Fetching page 150...
# ✅ Page 150 scraped. Total movies so far: 3000
#
# 🔄 Fetching page 151...
# ✅ Page 151 scraped. Total movies so far: 3020
#
# 🔄 Fetching page 152...
# ✅ Page 152 scraped. Total movies so far: 3040
#
# 🔄 Fetching page 153...
# ✅ Page 153 scraped. Total movies so far: 3060
#
# 🔄 Fetching page 154...
# ✅ Page 154 scraped. Total movies so far: 3080
#
# 🔄 Fetching page 155...
# ✅ Page 155 scraped. Total movies so far: 3100
#
# 🔄 Fetching page 156...
# ✅ Page 156 scraped. Total movies so far: 3120
#
# 🔄 Fetching page 157...
# ✅ Page 157 scraped. Total movies so far: 3140
#
# 🔄 Fetching page 158...
# ✅ Page 158 scraped. Total movies so far: 3160
#
# 🔄 Fetching page 159...
# ✅ Page 159 scraped. Total movies so far: 3180
#
# 🔄 Fetching page 160...
# ✅ Page 160 scraped. Total movies so far: 3200
#
# 🔄 Fetching page 161...
# ✅ Page 161 scraped. Total movies so far: 3220
#
# 🔄 Fetching page 162...
# ✅ Page 162 scraped. Total movies so far: 3240
#
# 🔄 Fetching page 163...
# ✅ Page 163 scraped. Total movies so far: 3260
#
# 🔄 Fetching page 164...
# ✅ Page 164 scraped. Total movies so far: 3280
#
# 🔄 Fetching page 165...
# ✅ Page 165 scraped. Total movies so far: 3300
#
# 🔄 Fetching page 166...
# ✅ Page 166 scraped. Total movies so far: 3320
#
# 🔄 Fetching page 167...
# ✅ Page 167 scraped. Total movies so far: 3340
#
# 🔄 Fetching page 168...
# ✅ Page 168 scraped. Total movies so far: 3360
#
# 🔄 Fetching page 169...
# ✅ Page 169 scraped. Total movies so far: 3380
#
# 🔄 Fetching page 170...
# ✅ Page 170 scraped. Total movies so far: 3400
#
# 🔄 Fetching page 171...
# ✅ Page 171 scraped. Total movies so far: 3420
#
# 🔄 Fetching page 172...
# ✅ Page 172 scraped. Total movies so far: 3440
#
# 🔄 Fetching page 173...
# ✅ Page 173 scraped. Total movies so far: 3460
#
# 🔄 Fetching page 174...
# ✅ Page 174 scraped. Total movies so far: 3480
#
# 🔄 Fetching page 175...
# ✅ Page 175 scraped. Total movies so far: 3500
#
# 🔄 Fetching page 176...
# ✅ Page 176 scraped. Total movies so far: 3520
#
# 🔄 Fetching page 177...
# ✅ Page 177 scraped. Total movies so far: 3540
#
# 🔄 Fetching page 178...
# ✅ Page 178 scraped. Total movies so far: 3560
#
# 🔄 Fetching page 179...
# ✅ Page 179 scraped. Total movies so far: 3580
#
# 🔄 Fetching page 180...
# ✅ Page 180 scraped. Total movies so far: 3600
#
# 🔄 Fetching page 181...
# ✅ Page 181 scraped. Total movies so far: 3620
#
# 🔄 Fetching page 182...
# ✅ Page 182 scraped. Total movies so far: 3640
#
# 🔄 Fetching page 183...
# ✅ Page 183 scraped. Total movies so far: 3660
#
# 🔄 Fetching page 184...
# ✅ Page 184 scraped. Total movies so far: 3680
#
# 🔄 Fetching page 185...
# ✅ Page 185 scraped. Total movies so far: 3700
#
# 🔄 Fetching page 186...
# ✅ Page 186 scraped. Total movies so far: 3720
#
# 🔄 Fetching page 187...
# ✅ Page 187 scraped. Total movies so far: 3740
#
# 🔄 Fetching page 188...
# ✅ Page 188 scraped. Total movies so far: 3760
#
# 🔄 Fetching page 189...
# ✅ Page 189 scraped. Total movies so far: 3780
#
# 🔄 Fetching page 190...
# ✅ Page 190 scraped. Total movies so far: 3800
#
# 🔄 Fetching page 191...
# ✅ Page 191 scraped. Total movies so far: 3820
#
# 🔄 Fetching page 192...
# ✅ Page 192 scraped. Total movies so far: 3840
#
# 🔄 Fetching page 193...
# ✅ Page 193 scraped. Total movies so far: 3860
#
# 🔄 Fetching page 194...
# ✅ Page 194 scraped. Total movies so far: 3880
#
# 🔄 Fetching page 195...
# ✅ Page 195 scraped. Total movies so far: 3900
#
# 🔄 Fetching page 196...
# ✅ Page 196 scraped. Total movies so far: 3920
#
# 🔄 Fetching page 197...
# ✅ Page 197 scraped. Total movies so far: 3940
#
# 🔄 Fetching page 198...
# ✅ Page 198 scraped. Total movies so far: 3960
#
# 🔄 Fetching page 199...
# ✅ Page 199 scraped. Total movies so far: 3980
#
# 🔄 Fetching page 200...
# ✅ Page 200 scraped. Total movies so far: 4000
#
# 🔄 Fetching page 201...
# ✅ Page 201 scraped. Total movies so far: 4020
#
# 🔄 Fetching page 202...
# ✅ Page 202 scraped. Total movies so far: 4040
#
# 🔄 Fetching page 203...
# ✅ Page 203 scraped. Total movies so far: 4060
#
# 🔄 Fetching page 204...
# ✅ Page 204 scraped. Total movies so far: 4080
#
# 🔄 Fetching page 205...
# ✅ Page 205 scraped. Total movies so far: 4100
#
# 🔄 Fetching page 206...
# ✅ Page 206 scraped. Total movies so far: 4120
#
# 🔄 Fetching page 207...
# ✅ Page 207 scraped. Total movies so far: 4140
#
# 🔄 Fetching page 208...
# ✅ Page 208 scraped. Total movies so far: 4160
#
# 🔄 Fetching page 209...
# ✅ Page 209 scraped. Total movies so far: 4180
#
# 🔄 Fetching page 210...
# ✅ Page 210 scraped. Total movies so far: 4200
#
# 🔄 Fetching page 211...
# ✅ Page 211 scraped. Total movies so far: 4220
#
# 🔄 Fetching page 212...
# ✅ Page 212 scraped. Total movies so far: 4240
#
# 🔄 Fetching page 213...
# ✅ Page 213 scraped. Total movies so far: 4260
#
# 🔄 Fetching page 214...
# ✅ Page 214 scraped. Total movies so far: 4280
#
# 🔄 Fetching page 215...
# ✅ Page 215 scraped. Total movies so far: 4300
#
# 🔄 Fetching page 216...
# ✅ Page 216 scraped. Total movies so far: 4320
#
# 🔄 Fetching page 217...
# ✅ Page 217 scraped. Total movies so far: 4340
#
# 🔄 Fetching page 218...
# ✅ Page 218 scraped. Total movies so far: 4360
#
# 🔄 Fetching page 219...
# ✅ Page 219 scraped. Total movies so far: 4380
#
# 🔄 Fetching page 220...
# ✅ Page 220 scraped. Total movies so far: 4400
#
# 🔄 Fetching page 221...
# ✅ Page 221 scraped. Total movies so far: 4420
#
# 🔄 Fetching page 222...
# ✅ Page 222 scraped. Total movies so far: 4440
#
# 🔄 Fetching page 223...
# ✅ Page 223 scraped. Total movies so far: 4460
#
# 🔄 Fetching page 224...
# ✅ Page 224 scraped. Total movies so far: 4480
#
# 🔄 Fetching page 225...
# ✅ Page 225 scraped. Total movies so far: 4500
#
# 🔄 Fetching page 226...
# ✅ Page 226 scraped. Total movies so far: 4520
#
# 🔄 Fetching page 227...
# ✅ Page 227 scraped. Total movies so far: 4540
#
# 🔄 Fetching page 228...
# ✅ Page 228 scraped. Total movies so far: 4560
#
# 🔄 Fetching page 229...
# ✅ Page 229 scraped. Total movies so far: 4580
#
# 🔄 Fetching page 230...
# ✅ Page 230 scraped. Total movies so far: 4600
#
# 🔄 Fetching page 231...
# ✅ Page 231 scraped. Total movies so far: 4620
#
# 🔄 Fetching page 232...
# ✅ Page 232 scraped. Total movies so far: 4640
#
# 🔄 Fetching page 233...
# ✅ Page 233 scraped. Total movies so far: 4660
#
# 🔄 Fetching page 234...
# ✅ Page 234 scraped. Total movies so far: 4680
#
# 🔄 Fetching page 235...
# ✅ Page 235 scraped. Total movies so far: 4700
#
# 🔄 Fetching page 236...
# ✅ Page 236 scraped. Total movies so far: 4720
#
# 🔄 Fetching page 237...
# ✅ Page 237 scraped. Total movies so far: 4740
#
# 🔄 Fetching page 238...
# ✅ Page 238 scraped. Total movies so far: 4760
#
# 🔄 Fetching page 239...
# ✅ Page 239 scraped. Total movies so far: 4780
#
# 🔄 Fetching page 240...
# ✅ Page 240 scraped. Total movies so far: 4800
#
# 🔄 Fetching page 241...
# ✅ Page 241 scraped. Total movies so far: 4820
#
# 🔄 Fetching page 242...
# ✅ Page 242 scraped. Total movies so far: 4840
#
# 🔄 Fetching page 243...
# ✅ Page 243 scraped. Total movies so far: 4860
#
# 🔄 Fetching page 244...
# ✅ Page 244 scraped. Total movies so far: 4880
#
# 🔄 Fetching page 245...
# ✅ Page 245 scraped. Total movies so far: 4900
#
# 🔄 Fetching page 246...
# ✅ Page 246 scraped. Total movies so far: 4920
#
# 🔄 Fetching page 247...
# ✅ Page 247 scraped. Total movies so far: 4940
#
# 🔄 Fetching page 248...
# ✅ Page 248 scraped. Total movies so far: 4960
#
# 🔄 Fetching page 249...
# ✅ Page 249 scraped. Total movies so far: 4980
#
# 🔄 Fetching page 250...
# ✅ Page 250 scraped. Total movies so far: 5000
#
# 🔄 Fetching page 251...
# ✅ Page 251 scraped. Total movies so far: 5020
#
# 🔄 Fetching page 252...
# ✅ Page 252 scraped. Total movies so far: 5040
#
# 🔄 Fetching page 253...
# ✅ Page 253 scraped. Total movies so far: 5060
#
# 🔄 Fetching page 254...
# ✅ Page 254 scraped. Total movies so far: 5080
#
# 🔄 Fetching page 255...
# ✅ Page 255 scraped. Total movies so far: 5100
#
# 🔄 Fetching page 256...
# ✅ Page 256 scraped. Total movies so far: 5120
#
# 🔄 Fetching page 257...
# ✅ Page 257 scraped. Total movies so far: 5140
#
# 🔄 Fetching page 258...
# ✅ Page 258 scraped. Total movies so far: 5160
#
# 🔄 Fetching page 259...
# ✅ Page 259 scraped. Total movies so far: 5180
#
# 🔄 Fetching page 260...
# ✅ Page 260 scraped. Total movies so far: 5200
#
# 🔄 Fetching page 261...
# ✅ Page 261 scraped. Total movies so far: 5220
#
# 🔄 Fetching page 262...
# ✅ Page 262 scraped. Total movies so far: 5240
#
# 🔄 Fetching page 263...
# ✅ Page 263 scraped. Total movies so far: 5260
#
# 🔄 Fetching page 264...
# ✅ Page 264 scraped. Total movies so far: 5280
#
# 🔄 Fetching page 265...
# ✅ Page 265 scraped. Total movies so far: 5300
#
# 🔄 Fetching page 266...
# ✅ Page 266 scraped. Total movies so far: 5320
#
# 🔄 Fetching page 267...
# ✅ Page 267 scraped. Total movies so far: 5340
#
# 🔄 Fetching page 268...
# ✅ Page 268 scraped. Total movies so far: 5360
#
# 🔄 Fetching page 269...
# ✅ Page 269 scraped. Total movies so far: 5380
#
# 🔄 Fetching page 270...
# ✅ Page 270 scraped. Total movies so far: 5400
#
# 🔄 Fetching page 271...
# ✅ Page 271 scraped. Total movies so far: 5420
#
# 🔄 Fetching page 272...
# ✅ Page 272 scraped. Total movies so far: 5440
#
# 🔄 Fetching page 273...
# ✅ Page 273 scraped. Total movies so far: 5460
#
# 🔄 Fetching page 274...
# ✅ Page 274 scraped. Total movies so far: 5480
#
# 🔄 Fetching page 275...
# ✅ Page 275 scraped. Total movies so far: 5500
#
# 🔄 Fetching page 276...
# ✅ Page 276 scraped. Total movies so far: 5520
#
# 🔄 Fetching page 277...
# ✅ Page 277 scraped. Total movies so far: 5540
#
# 🔄 Fetching page 278...
# ✅ Page 278 scraped. Total movies so far: 5560
#
# 🔄 Fetching page 279...
# ✅ Page 279 scraped. Total movies so far: 5580
#
# 🔄 Fetching page 280...
# ✅ Page 280 scraped. Total movies so far: 5600
#
# 🔄 Fetching page 281...
# ✅ Page 281 scraped. Total movies so far: 5620
#
# 🔄 Fetching page 282...
# ✅ Page 282 scraped. Total movies so far: 5640
#
# 🔄 Fetching page 283...
# ✅ Page 283 scraped. Total movies so far: 5660
#
# 🔄 Fetching page 284...
# ✅ Page 284 scraped. Total movies so far: 5680
#
# 🔄 Fetching page 285...
# ✅ Page 285 scraped. Total movies so far: 5700
#
# 🔄 Fetching page 286...
# ✅ Page 286 scraped. Total movies so far: 5720
#
# 🔄 Fetching page 287...
# ✅ Page 287 scraped. Total movies so far: 5740
#
# 🔄 Fetching page 288...
# ✅ Page 288 scraped. Total movies so far: 5760
#
# 🔄 Fetching page 289...
# ✅ Page 289 scraped. Total movies so far: 5780
#
# 🔄 Fetching page 290...
# ✅ Page 290 scraped. Total movies so far: 5800
#
# 🔄 Fetching page 291...
# ✅ Page 291 scraped. Total movies so far: 5820
#
# 🔄 Fetching page 292...
# ✅ Page 292 scraped. Total movies so far: 5840
#
# 🔄 Fetching page 293...
# ✅ Page 293 scraped. Total movies so far: 5860
#
# 🔄 Fetching page 294...
# ✅ Page 294 scraped. Total movies so far: 5880
#
# 🔄 Fetching page 295...
# ✅ Page 295 scraped. Total movies so far: 5900
#
# 🔄 Fetching page 296...
# ✅ Page 296 scraped. Total movies so far: 5920
#
# 🔄 Fetching page 297...
# ✅ Page 297 scraped. Total movies so far: 5940
#
# 🔄 Fetching page 298...
# ✅ Page 298 scraped. Total movies so far: 5960
#
# 🔄 Fetching page 299...
# ✅ Page 299 scraped. Total movies so far: 5980
#
# 🔄 Fetching page 300...
# ✅ Page 300 scraped. Total movies so far: 6000
#
# 🔄 Fetching page 301...
# ✅ Page 301 scraped. Total movies so far: 6020
#
# 🔄 Fetching page 302...
# ✅ Page 302 scraped. Total movies so far: 6040
#
# 🔄 Fetching page 303...
# ✅ Page 303 scraped. Total movies so far: 6060
#
# 🔄 Fetching page 304...
# ✅ Page 304 scraped. Total movies so far: 6080
#
# 🔄 Fetching page 305...
# ✅ Page 305 scraped. Total movies so far: 6100
#
# 🔄 Fetching page 306...
# ✅ Page 306 scraped. Total movies so far: 6120
#
# 🔄 Fetching page 307...
# ✅ Page 307 scraped. Total movies so far: 6140
#
# 🔄 Fetching page 308...
# ✅ Page 308 scraped. Total movies so far: 6160
#
# 🔄 Fetching page 309...
# ✅ Page 309 scraped. Total movies so far: 6180
#
# 🔄 Fetching page 310...
# ✅ Page 310 scraped. Total movies so far: 6200
#
# 🔄 Fetching page 311...
# ✅ Page 311 scraped. Total movies so far: 6220
#
# 🔄 Fetching page 312...
# ✅ Page 312 scraped. Total movies so far: 6240
#
# 🔄 Fetching page 313...
# ✅ Page 313 scraped. Total movies so far: 6260
#
# 🔄 Fetching page 314...
# ✅ Page 314 scraped. Total movies so far: 6280
#
# 🔄 Fetching page 315...
# ✅ Page 315 scraped. Total movies so far: 6300
#
# 🔄 Fetching page 316...
# ✅ Page 316 scraped. Total movies so far: 6320
#
# 🔄 Fetching page 317...
# ✅ Page 317 scraped. Total movies so far: 6340
#
# 🔄 Fetching page 318...
# ✅ Page 318 scraped. Total movies so far: 6360
#
# 🔄 Fetching page 319...
# ✅ Page 319 scraped. Total movies so far: 6380
#
# 🔄 Fetching page 320...
# ✅ Page 320 scraped. Total movies so far: 6400
#
# 🔄 Fetching page 321...
# ✅ Page 321 scraped. Total movies so far: 6420
#
# 🔄 Fetching page 322...
# ✅ Page 322 scraped. Total movies so far: 6440
#
# 🔄 Fetching page 323...
# ✅ Page 323 scraped. Total movies so far: 6460
#
# 🔄 Fetching page 324...
# ✅ Page 324 scraped. Total movies so far: 6480
#
# 🔄 Fetching page 325...
# ✅ Page 325 scraped. Total movies so far: 6500
#
# 🔄 Fetching page 326...
# ✅ Page 326 scraped. Total movies so far: 6520
#
# 🔄 Fetching page 327...
# ✅ Page 327 scraped. Total movies so far: 6540
#
# 🔄 Fetching page 328...
# ✅ Page 328 scraped. Total movies so far: 6560
#
# 🔄 Fetching page 329...
# ✅ Page 329 scraped. Total movies so far: 6580
#
# 🔄 Fetching page 330...
# ✅ Page 330 scraped. Total movies so far: 6600
#
# 🔄 Fetching page 331...
# ✅ Page 331 scraped. Total movies so far: 6620
#
# 🔄 Fetching page 332...
# ✅ Page 332 scraped. Total movies so far: 6640
#
# 🔄 Fetching page 333...
# ✅ Page 333 scraped. Total movies so far: 6660
#
# 🔄 Fetching page 334...
# ✅ Page 334 scraped. Total movies so far: 6680
#
# 🔄 Fetching page 335...
# ✅ Page 335 scraped. Total movies so far: 6700
#
# 🔄 Fetching page 336...
# ✅ Page 336 scraped. Total movies so far: 6720
#
# 🔄 Fetching page 337...
# ✅ Page 337 scraped. Total movies so far: 6740
#
# 🔄 Fetching page 338...
# ✅ Page 338 scraped. Total movies so far: 6760
#
# 🔄 Fetching page 339...
# ✅ Page 339 scraped. Total movies so far: 6780
#
# 🔄 Fetching page 340...
# ✅ Page 340 scraped. Total movies so far: 6800
#
# 🔄 Fetching page 341...
# ✅ Page 341 scraped. Total movies so far: 6820
#
# 🔄 Fetching page 342...
# ✅ Page 342 scraped. Total movies so far: 6840
#
# 🔄 Fetching page 343...
# ✅ Page 343 scraped. Total movies so far: 6860
#
# 🔄 Fetching page 344...
# ✅ Page 344 scraped. Total movies so far: 6880
#
# 🔄 Fetching page 345...
# ✅ Page 345 scraped. Total movies so far: 6900
#
# 🔄 Fetching page 346...
# ✅ Page 346 scraped. Total movies so far: 6920
#
# 🔄 Fetching page 347...
# ✅ Page 347 scraped. Total movies so far: 6940
#
# 🔄 Fetching page 348...
# ✅ Page 348 scraped. Total movies so far: 6960
#
# 🔄 Fetching page 349...
# ✅ Page 349 scraped. Total movies so far: 6980
#
# 🔄 Fetching page 350...
# ✅ Page 350 scraped. Total movies so far: 7000
#
# 🔄 Fetching page 351...
# ✅ Page 351 scraped. Total movies so far: 7020
#
# 🔄 Fetching page 352...
# ✅ Page 352 scraped. Total movies so far: 7040
#
# 🔄 Fetching page 353...
# ✅ Page 353 scraped. Total movies so far: 7060
#
# 🔄 Fetching page 354...
# ✅ Page 354 scraped. Total movies so far: 7080
#
# 🔄 Fetching page 355...
# ✅ Page 355 scraped. Total movies so far: 7100
#
# 🔄 Fetching page 356...
# ✅ Page 356 scraped. Total movies so far: 7120
#
# 🔄 Fetching page 357...
# ✅ Page 357 scraped. Total movies so far: 7140
#
# 🔄 Fetching page 358...
# ✅ Page 358 scraped. Total movies so far: 7160
#
# 🔄 Fetching page 359...
# ✅ Page 359 scraped. Total movies so far: 7180
#
# 🔄 Fetching page 360...
# ✅ Page 360 scraped. Total movies so far: 7200
#
# 🔄 Fetching page 361...
# ✅ Page 361 scraped. Total movies so far: 7220
#
# 🔄 Fetching page 362...
# ✅ Page 362 scraped. Total movies so far: 7240
#
# 🔄 Fetching page 363...
# ✅ Page 363 scraped. Total movies so far: 7260
#
# 🔄 Fetching page 364...
# ✅ Page 364 scraped. Total movies so far: 7280
#
# 🔄 Fetching page 365...
# ✅ Page 365 scraped. Total movies so far: 7300
#
# 🔄 Fetching page 366...
# ✅ Page 366 scraped. Total movies so far: 7320
#
# 🔄 Fetching page 367...
# ✅ Page 367 scraped. Total movies so far: 7340
#
# 🔄 Fetching page 368...
# ✅ Page 368 scraped. Total movies so far: 7360
#
# 🔄 Fetching page 369...
# ✅ Page 369 scraped. Total movies so far: 7380
#
# 🔄 Fetching page 370...
# ✅ Page 370 scraped. Total movies so far: 7400
#
# 🔄 Fetching page 371...
# ✅ Page 371 scraped. Total movies so far: 7420
#
# 🔄 Fetching page 372...
# ✅ Page 372 scraped. Total movies so far: 7440
#
# 🔄 Fetching page 373...
# ✅ Page 373 scraped. Total movies so far: 7460
#
# 🔄 Fetching page 374...
# ✅ Page 374 scraped. Total movies so far: 7480
#
# 🔄 Fetching page 375...
# ✅ Page 375 scraped. Total movies so far: 7500
#
# 🔄 Fetching page 376...
# ✅ Page 376 scraped. Total movies so far: 7520
#
# 🔄 Fetching page 377...
# ✅ Page 377 scraped. Total movies so far: 7540
#
# 🔄 Fetching page 378...
# ✅ Page 378 scraped. Total movies so far: 7560
#
# 🔄 Fetching page 379...
# ✅ Page 379 scraped. Total movies so far: 7580
#
# 🔄 Fetching page 380...
# ✅ Page 380 scraped. Total movies so far: 7600
#
# 🔄 Fetching page 381...
# ✅ Page 381 scraped. Total movies so far: 7620
#
# 🔄 Fetching page 382...
# ✅ Page 382 scraped. Total movies so far: 7640
#
# 🔄 Fetching page 383...
# ✅ Page 383 scraped. Total movies so far: 7660
#
# 🔄 Fetching page 384...
# ✅ Page 384 scraped. Total movies so far: 7680
#
# 🔄 Fetching page 385...
# ✅ Page 385 scraped. Total movies so far: 7700
#
# 🔄 Fetching page 386...
# ✅ Page 386 scraped. Total movies so far: 7720
#
# 🔄 Fetching page 387...
# ✅ Page 387 scraped. Total movies so far: 7740
#
# 🔄 Fetching page 388...
# ✅ Page 388 scraped. Total movies so far: 7760
#
# 🔄 Fetching page 389...
# ✅ Page 389 scraped. Total movies so far: 7780
#
# 🔄 Fetching page 390...
# ✅ Page 390 scraped. Total movies so far: 7800
#
# 🔄 Fetching page 391...
# ✅ Page 391 scraped. Total movies so far: 7820
#
# 🔄 Fetching page 392...
# ✅ Page 392 scraped. Total movies so far: 7840
#
# 🔄 Fetching page 393...
# ✅ Page 393 scraped. Total movies so far: 7860
#
# 🔄 Fetching page 394...
# ✅ Page 394 scraped. Total movies so far: 7880
#
# 🔄 Fetching page 395...
# ✅ Page 395 scraped. Total movies so far: 7900
#
# 🔄 Fetching page 396...
# ✅ Page 396 scraped. Total movies so far: 7920
#
# 🔄 Fetching page 397...
# ✅ Page 397 scraped. Total movies so far: 7940
#
# 🔄 Fetching page 398...
# ✅ Page 398 scraped. Total movies so far: 7960
#
# 🔄 Fetching page 399...
# ✅ Page 399 scraped. Total movies so far: 7980
#
# 🔄 Fetching page 400...
# ✅ Page 400 scraped. Total movies so far: 8000
#
# 🔄 Fetching page 401...
# ✅ Page 401 scraped. Total movies so far: 8020
#
# 🔄 Fetching page 402...
# ✅ Page 402 scraped. Total movies so far: 8040
#
# 🔄 Fetching page 403...
# ✅ Page 403 scraped. Total movies so far: 8060
#
# 🔄 Fetching page 404...
# ✅ Page 404 scraped. Total movies so far: 8080
#
# 🔄 Fetching page 405...
# ✅ Page 405 scraped. Total movies so far: 8100
#
# 🔄 Fetching page 406...
# ✅ Page 406 scraped. Total movies so far: 8120
#
# 🔄 Fetching page 407...
# ✅ Page 407 scraped. Total movies so far: 8140
#
# 🔄 Fetching page 408...
# ✅ Page 408 scraped. Total movies so far: 8160
#
# 🔄 Fetching page 409...
# ✅ Page 409 scraped. Total movies so far: 8180
#
# 🔄 Fetching page 410...
# ✅ Page 410 scraped. Total movies so far: 8200
#
# 🔄 Fetching page 411...
# ✅ Page 411 scraped. Total movies so far: 8220
#
# 🔄 Fetching page 412...
# ✅ Page 412 scraped. Total movies so far: 8240
#
# 🔄 Fetching page 413...
# ✅ Page 413 scraped. Total movies so far: 8260
#
# 🔄 Fetching page 414...
# ✅ Page 414 scraped. Total movies so far: 8280
#
# 🔄 Fetching page 415...
# ✅ Page 415 scraped. Total movies so far: 8300
#
# 🔄 Fetching page 416...
# ✅ Page 416 scraped. Total movies so far: 8320
#
# 🔄 Fetching page 417...
# ✅ Page 417 scraped. Total movies so far: 8340
#
# 🔄 Fetching page 418...
# ✅ Page 418 scraped. Total movies so far: 8360
#
# 🔄 Fetching page 419...
# ✅ Page 419 scraped. Total movies so far: 8380
#
# 🔄 Fetching page 420...
# ✅ Page 420 scraped. Total movies so far: 8400
#
# 🔄 Fetching page 421...
# ✅ Page 421 scraped. Total movies so far: 8420
#
# 🔄 Fetching page 422...
# ✅ Page 422 scraped. Total movies so far: 8440
#
# 🔄 Fetching page 423...
# ✅ Page 423 scraped. Total movies so far: 8460
#
# 🔄 Fetching page 424...
# ✅ Page 424 scraped. Total movies so far: 8480
#
# 🔄 Fetching page 425...
# ✅ Page 425 scraped. Total movies so far: 8500
#
# 🔄 Fetching page 426...
# ✅ Page 426 scraped. Total movies so far: 8520
#
# 🔄 Fetching page 427...
# ✅ Page 427 scraped. Total movies so far: 8540
#
# 🔄 Fetching page 428...
# ✅ Page 428 scraped. Total movies so far: 8560
#
# 🔄 Fetching page 429...
# ✅ Page 429 scraped. Total movies so far: 8580
#
# 🔄 Fetching page 430...
# ✅ Page 430 scraped. Total movies so far: 8600
#
# 🔄 Fetching page 431...
# ✅ Page 431 scraped. Total movies so far: 8620
#
# 🔄 Fetching page 432...
# ✅ Page 432 scraped. Total movies so far: 8640
#
# 🔄 Fetching page 433...
# ✅ Page 433 scraped. Total movies so far: 8660
#
# 🔄 Fetching page 434...
# ✅ Page 434 scraped. Total movies so far: 8680
#
# 🔄 Fetching page 435...
# ✅ Page 435 scraped. Total movies so far: 8700
#
# 🔄 Fetching page 436...
# ✅ Page 436 scraped. Total movies so far: 8720
#
# 🔄 Fetching page 437...
# ✅ Page 437 scraped. Total movies so far: 8740
#
# 🔄 Fetching page 438...
# ✅ Page 438 scraped. Total movies so far: 8760
#
# 🔄 Fetching page 439...
# ✅ Page 439 scraped. Total movies so far: 8780
#
# 🔄 Fetching page 440...
# ✅ Page 440 scraped. Total movies so far: 8800
#
# 🔄 Fetching page 441...
# ✅ Page 441 scraped. Total movies so far: 8820
#
# 🔄 Fetching page 442...
# ✅ Page 442 scraped. Total movies so far: 8840
#
# 🔄 Fetching page 443...
# ✅ Page 443 scraped. Total movies so far: 8860
#
# 🔄 Fetching page 444...
# ✅ Page 444 scraped. Total movies so far: 8880
#
# 🔄 Fetching page 445...
# ✅ Page 445 scraped. Total movies so far: 8900
#
# 🔄 Fetching page 446...
# ✅ Page 446 scraped. Total movies so far: 8920
#
# 🔄 Fetching page 447...
# ✅ Page 447 scraped. Total movies so far: 8940
#
# 🔄 Fetching page 448...
# ✅ Page 448 scraped. Total movies so far: 8960
#
# 🔄 Fetching page 449...
# ✅ Page 449 scraped. Total movies so far: 8980
#
# 🔄 Fetching page 450...
# ✅ Page 450 scraped. Total movies so far: 9000
#
# 🔄 Fetching page 451...
# ✅ Page 451 scraped. Total movies so far: 9020
#
# 🔄 Fetching page 452...
# ✅ Page 452 scraped. Total movies so far: 9040
#
# 🔄 Fetching page 453...
# ✅ Page 453 scraped. Total movies so far: 9060
#
# 🔄 Fetching page 454...
# ✅ Page 454 scraped. Total movies so far: 9080
#
# 🔄 Fetching page 455...
# ✅ Page 455 scraped. Total movies so far: 9100
#
# 🔄 Fetching page 456...
# ✅ Page 456 scraped. Total movies so far: 9120
#
# 🔄 Fetching page 457...
# ✅ Page 457 scraped. Total movies so far: 9140
#
# 🔄 Fetching page 458...
# ✅ Page 458 scraped. Total movies so far: 9160
#
# 🔄 Fetching page 459...
# ✅ Page 459 scraped. Total movies so far: 9180
#
# 🔄 Fetching page 460...
# ✅ Page 460 scraped. Total movies so far: 9200
#
# 🔄 Fetching page 461...
# ✅ Page 461 scraped. Total movies so far: 9220
#
# 🔄 Fetching page 462...
# ✅ Page 462 scraped. Total movies so far: 9240
#
# 🔄 Fetching page 463...
# ✅ Page 463 scraped. Total movies so far: 9260
#
# 🔄 Fetching page 464...
# ✅ Page 464 scraped. Total movies so far: 9280
#
# 🔄 Fetching page 465...
# ✅ Page 465 scraped. Total movies so far: 9300
#
# 🔄 Fetching page 466...
# ✅ Page 466 scraped. Total movies so far: 9320
#
# 🔄 Fetching page 467...
# ✅ Page 467 scraped. Total movies so far: 9340
#
# 🔄 Fetching page 468...
# ✅ Page 468 scraped. Total movies so far: 9360
#
# 🔄 Fetching page 469...
# ✅ Page 469 scraped. Total movies so far: 9380
#
# 🔄 Fetching page 470...
# ✅ Page 470 scraped. Total movies so far: 9400
#
# 🔄 Fetching page 471...
# ✅ Page 471 scraped. Total movies so far: 9420
#
# 🔄 Fetching page 472...
# ✅ Page 472 scraped. Total movies so far: 9440
#
# 🔄 Fetching page 473...
# ✅ Page 473 scraped. Total movies so far: 9460
#
# 🔄 Fetching page 474...
# ✅ Page 474 scraped. Total movies so far: 9480
#
# 🔄 Fetching page 475...
# ✅ Page 475 scraped. Total movies so far: 9500
#
# 🔄 Fetching page 476...
# ✅ Page 476 scraped. Total movies so far: 9520
#
# 🔄 Fetching page 477...
# ✅ Page 477 scraped. Total movies so far: 9540
#
# 🔄 Fetching page 478...
# ✅ Page 478 scraped. Total movies so far: 9560
#
# 🔄 Fetching page 479...
# ✅ Page 479 scraped. Total movies so far: 9580
#
# 🔄 Fetching page 480...
# ✅ Page 480 scraped. Total movies so far: 9600
#
# 📁 Done! Saved 9600 movies to 'tmdb_movies_with_genres.csv'.

# %%
import requests
import pandas as pd
import time

api_key = "my-api-key"  # hidden for privacy
existing_csv = "tmdb_movies.csv"  # Your previous file

# Load previously scraped movies
try:
    existing_df = pd.read_csv(existing_csv)
    scraped_titles = set(existing_df['Title'].dropna().unique())
    print(f"🔄 Loaded {len(scraped_titles)} existing titles to avoid duplication.")
except FileNotFoundError:
    existing_df = pd.DataFrame()
    scraped_titles = set()
    print("⚠️ No existing file found. Starting fresh.")

# Get genre name mapping from TMDb
def get_genre_mapping(api_key):
    print("Fetching genre mapping...")
    url = f"https://api.themoviedb.org/3/genre/movie/list?api_key={api_key}&language=en-US"
    response = requests.get(url)
    data = response.json()
    return {genre["id"]: genre["name"] for genre in data.get("genres", [])}

# Fetch movies by language
def fetch_movies_by_language(api_key, language, pages=500):
    print(f"\n🌐 Scraping movies for language: {language}")
    genre_map = get_genre_mapping(api_key)
    base_url = "https://api.themoviedb.org/3/discover/movie"
    new_movies = []

    for page in range(1, pages + 1):
        print(f"🔄 Language {language} | Page {page}")
        params = {
            "api_key": api_key,
            "language": "en-US",
            "sort_by": "popularity.desc",
            "page": page,
            "with_original_language": language
        }

        response = requests.get(base_url, params=params)
        if response.status_code != 200:
            print(f"❌ Error on page {page}: {response.status_code} {response.text}")
            break

        data = response.json()
        results = data.get("results", [])
        if not results:
            break

        for movie in results:
            title = movie.get("title", "").strip()
            if title in scraped_titles:
                continue

            genre_names = [genre_map.get(gid, "Unknown") for gid in movie.get("genre_ids", [])]
            genre_str = ", ".join(genre_names)

            new_movies.append([
                title,
                movie.get("release_date"),
                movie.get("vote_average"),
                movie.get("vote_count"),
                movie.get("original_language"),
                movie.get("overview"),
                movie.get("popularity"),
                genre_str
            ])
            scraped_titles.add(title)

        print(f"✅ Page {page} done. Movies collected: {len(new_movies)}\n")
        time.sleep(0.5)

    return new_movies

# Main driver
def main():
    languages = ["hi", "fr", "es", "ja", "ko", "de", "ru", "zh", "pt"]  # skip "en" for now
    all_new_movies = []

    for lang in languages:
        new_data = fetch_movies_by_language(api_key, lang)
        all_new_movies.extend(new_data)

    if all_new_movies:
        new_df = pd.DataFrame(all_new_movies, columns=[
            "Title", "Release Date", "Rating", "Vote Count",
            "Language", "Overview", "Popularity", "Genres"
        ])
        combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        combined_df.to_csv(existing_csv, index=False)
        print(f"🎉 Done! Added {len(new_df)} new movies. Total now: {len(combined_df)}")
    else:
        print("⚠️ No new movies added.")

main()
# Out:
# 🔄 Loaded 9325 existing titles to avoid duplication.
#
# 🌐 Scraping movies for language: hi
# Fetching genre mapping...
# 🔄 Language hi | Page 1
# ✅ Page 1 done. Movies collected: 0
#
# 🔄 Language hi | Page 2
# ✅ Page 2 done. Movies collected: 1
#
# 🔄 Language hi | Page 3
# ✅ Page 3 done. Movies collected: 3
#
# 🔄 Language hi | Page 4
# ✅ Page 4 done. Movies collected: 3
#
# 🔄 Language hi | Page 5
# ✅ Page 5 done. Movies collected: 3
#
# 🔄 Language hi | Page 6
# ✅ Page 6 done. Movies collected: 5
#
# 🔄 Language hi | Page 7
# ✅ Page 7 done. Movies collected: 6
#
# 🔄 Language hi | Page 8
# ✅ Page 8 done. Movies collected: 7
#
# 🔄 Language hi | Page 9
# ✅ Page 9 done. Movies collected: 11
#
# 🔄 Language hi | Page 10
# ✅ Page 10 done. Movies collected: 19
#
# 🔄 Language hi | Page 11
# ✅ Page 11 done. Movies collected: 25
#
# 🔄 Language hi | Page 12
# ✅ Page 12 done. Movies collected: 35
#
# 🔄 Language hi | Page 13
# ✅ Page 13 done. Movies collected: 43
#
# 🔄 Language hi | Page 14
# ✅ Page 14 done. Movies collected: 57
#
# 🔄 Language hi | Page 15
# ✅ Page 15 done. Movies collected: 74
#
# 🔄 Language hi | Page 16
# ✅ Page 16 done. Movies collected: 90
#
# 🔄 Language hi | Page 17
# ✅ Page 17 done. Movies collected: 108
#
# 🔄 Language hi | Page 18
# ✅ Page 18 done. Movies collected: 127
#
# 🔄 Language hi | Page 19
# ✅ Page 19 done. Movies collected: 147
#
# 🔄 Language hi | Page 20
# ✅ Page 20 done. Movies collected: 166
#
# 🔄 Language hi | Page 21
# ✅ Page 21 done. Movies collected: 185
#
# 🔄 Language hi | Page 22
# ✅ Page 22 done. Movies collected: 202
#
# 🔄 Language hi | Page 23
# ✅ Page 23 done. Movies collected: 220
#
# 🔄 Language hi | Page 24
# ✅ Page 24 done. Movies collected: 240
#
# 🔄 Language hi | Page 25
# ✅ Page 25 done. Movies collected: 260
#
# 🔄 Language hi | Page 26
# ✅ Page 26 done. Movies collected: 278
#
# 🔄 Language hi | Page 27
# ✅ Page 27 done. Movies collected: 297
#
# 🔄 Language hi | Page 28
# ✅ Page 28 done. Movies collected: 317
#
# 🔄 Language hi | Page 29
# ✅ Page 29 done. Movies collected: 336
#
# 🔄 Language hi | Page 30
# ✅ Page 30 done. Movies collected: 354
#
# 🔄 Language hi | Page 31
# ✅ Page 31 done. Movies collected: 372
#
# 🔄 Language hi | Page 32
# ✅ Page 32 done. Movies collected: 392
#
# 🔄 Language hi | Page 33
# ✅ Page 33 done. Movies collected: 412
#
# 🔄 Language hi | Page 34
# ✅ Page 34 done. Movies collected: 432
#
# 🔄 Language hi | Page 35
# ✅ Page 35 done. Movies collected: 449
#
# 🔄 Language hi | Page 36
# ✅ Page 36 done. Movies collected: 466
#
# 🔄 Language hi | Page 37
# ✅ Page 37 done. Movies collected: 485
#
# 🔄 Language hi | Page 38
# ✅ Page 38 done. Movies collected: 504
#
# 🔄 Language hi | Page 39
# ✅ Page 39 done. Movies collected: 524
#
# 🔄 Language hi | Page 40
# ✅ Page 40 done. Movies collected: 544
#
# 🔄 Language hi | Page 41
# ✅ Page 41 done. Movies collected: 564
#
# 🔄 Language hi | Page 42
# ✅ Page 42 done. Movies collected: 583
#
# 🔄 Language hi | Page 43
# ✅ Page 43 done. Movies collected: 603
#
# 🔄 Language hi | Page 44
# ✅ Page 44 done. Movies collected: 621
#
# 🔄 Language hi | Page 45
# ✅ Page 45 done. Movies collected: 640
#
# 🔄 Language hi | Page 46
# ✅ Page 46 done. Movies collected: 660
#
# 🔄 Language hi | Page 47
# ✅ Page 47 done. Movies collected: 678
#
# 🔄 Language hi | Page 48
# ✅ Page 48 done. Movies collected: 697
#
# 🔄 Language hi | Page 49
# ✅ Page 49 done. Movies collected: 715
#
# 🔄 Language hi | Page 50
# ✅ Page 50 done. Movies collected: 735
#
# 🔄 Language hi | Page 51
# ✅ Page 51 done. Movies collected: 755
#
# 🔄 Language hi | Page 52
# ✅ Page 52 done. Movies collected: 772
#
# 🔄 Language hi | Page 53
# ✅ Page 53 done. Movies collected: 791
#
# 🔄 Language hi | Page 54
# ✅ Page 54 done. Movies collected: 811
#
# 🔄 Language hi | Page 55
# ✅ Page 55 done. Movies collected: 830
#
# 🔄 Language hi | Page 56
# ✅ Page 56 done. Movies collected: 849
#
# 🔄 Language hi | Page 57
# ✅ Page 57 done. Movies collected: 868
#
# 🔄 Language hi | Page 58
# ✅ Page 58 done. Movies collected: 888
#
# 🔄 Language hi | Page 59
# ✅ Page 59 done. Movies collected: 907
#
# 🔄 Language hi | Page 60
# ✅ Page 60 done. Movies collected: 926
#
# 🔄 Language hi | Page 61
# ✅ Page 61 done. Movies collected: 945
#
# 🔄 Language hi | Page 62
# ✅ Page 62 done. Movies collected: 961
#
# 🔄 Language hi | Page 63
# ✅ Page 63 done. Movies collected: 980
#
# 🔄 Language hi | Page 64
# ✅ Page 64 done. Movies collected: 999
#
# 🔄 Language hi | Page 65
# ✅ Page 65 done. Movies collected: 1018
#
# 🔄 Language hi | Page 66
# ✅ Page 66 done. Movies collected: 1036
#
# 🔄 Language hi | Page 67
# ✅ Page 67 done. Movies collected: 1055
#
# 🔄 Language hi | Page 68
# ✅ Page 68 done. Movies collected: 1073
#
# 🔄 Language hi | Page 69
# ✅ Page 69 done. Movies collected: 1092
#
# 🔄 Language hi | Page 70
# ✅ Page 70 done. Movies collected: 1111
#
# 🔄 Language hi | Page 71
# ✅ Page 71 done. Movies collected: 1127
#
# 🔄 Language hi | Page 72
# ✅ Page 72 done. Movies collected: 1147
#
# 🔄 Language hi | Page 73
# ✅ Page 73 done. Movies collected: 1167
#
# 🔄 Language hi | Page 74
# ✅ Page 74 done. Movies collected: 1183
#
# 🔄 Language hi | Page 75
# ✅ Page 75 done. Movies collected: 1202
#
# 🔄 Language hi | Page 76
# ✅ Page 76 done. Movies collected: 1218
#
# 🔄 Language hi | Page 77
# ✅ Page 77 done. Movies collected: 1236
#
# 🔄 Language hi | Page 78
# ✅ Page 78 done. Movies collected: 1255
#
# 🔄 Language hi | Page 79
# ✅ Page 79 done. Movies collected: 1272
#
# 🔄 Language hi | Page 80
# ✅ Page 80 done. Movies collected: 1288
#
# 🔄 Language hi | Page 81
# ✅ Page 81 done. Movies collected: 1308
#
# 🔄 Language hi | Page 82
# ✅ Page 82 done. Movies collected: 1328
#
# 🔄 Language hi | Page 83
# ✅ Page 83 done. Movies collected: 1347
#
# 🔄 Language hi | Page 84
# ✅ Page 84 done. Movies collected: 1366
#
# 🔄 Language hi | Page 85
# ✅ Page 85 done. Movies collected: 1384
#
# 🔄 Language hi | Page 86
# ✅ Page 86 done. Movies collected: 1402
#
# 🔄 Language hi | Page 87
# ✅ Page 87 done. Movies collected: 1420
#
# 🔄 Language hi | Page 88
# ✅ Page 88 done. Movies collected: 1438
#
# 🔄 Language hi | Page 89
# ✅ Page 89 done. Movies collected: 1456
#
# 🔄 Language hi | Page 90
# ✅ Page 90 done. Movies collected: 1475
#
# 🔄 Language hi | Page 91
# ✅ Page 91 done. Movies collected: 1495
#
# 🔄 Language hi | Page 92
# ✅ Page 92 done. Movies collected: 1515
#
# 🔄 Language hi | Page 93
# ✅ Page 93 done. Movies collected: 1533
#
# 🔄 Language hi | Page 94
# ✅ Page 94 done. Movies collected: 1552
#
# 🔄 Language hi | Page 95
# ✅ Page 95 done. Movies collected: 1569
#
# 🔄 Language hi | Page 96
# ✅ Page 96 done. Movies collected: 1588
#
# 🔄 Language hi | Page 97
# ✅ Page 97 done. Movies collected: 1608
#
# 🔄 Language hi | Page 98
# ✅ Page 98 done. Movies collected: 1626
#
# 🔄 Language hi | Page 99
# ✅ Page 99 done. Movies collected: 1643
#
# 🔄 Language hi | Page 100
# ✅ Page 100 done. Movies collected: 1660
#
# 🔄 Language hi | Page 101
# ✅ Page 101 done. Movies collected: 1678
#
# 🔄 Language hi | Page 102
# ✅ Page 102 done. Movies collected: 1695
#
# 🔄 Language hi | Page 103
# ✅ Page 103 done. Movies collected: 1715
#
# 🔄 Language hi | Page 104
# ✅ Page 104 done. Movies collected: 1734
#
# 🔄 Language hi | Page 105
# ✅ Page 105 done. Movies collected: 1750
#
# 🔄 Language hi | Page 106
# ✅ Page 106 done. Movies collected: 1768
#
# 🔄 Language hi | Page 107
# ✅ Page 107 done. Movies collected: 1785
#
# 🔄 Language hi | Page 108
# ✅ Page 108 done. Movies collected: 1805
#
# 🔄 Language hi | Page 109
# ✅ Page 109 done. Movies collected: 1824
#
# 🔄 Language hi | Page 110
# ✅ Page 110 done. Movies collected: 1841
#
# 🔄 Language hi | Page 111
# ✅ Page 111 done. Movies collected: 1861
#
# 🔄 Language hi | Page 112
# ✅ Page 112 done. Movies collected: 1879
#
# 🔄 Language hi | Page 113
# ✅ Page 113 done. Movies collected: 1897
#
# 🔄 Language hi | Page 114
# ✅ Page 114 done. Movies collected: 1917
#
# 🔄 Language hi | Page 115
# ✅ Page 115 done. Movies collected: 1935
#
# 🔄 Language hi | Page 116
# ✅ Page 116 done. Movies collected: 1954
#
# 🔄 Language hi | Page 117
# ✅ Page 117 done. Movies collected: 1972
#
# 🔄 Language hi | Page 118
# ✅ Page 118 done. Movies collected: 1988
#
# 🔄 Language hi | Page 119
# ✅ Page 119 done. Movies collected: 2005
#
# 🔄 Language hi | Page 120
# ✅ Page 120 done. Movies collected: 2023
#
# 🔄 Language hi | Page 121
# ✅ Page 121 done. Movies collected: 2042
#
# 🔄 Language hi | Page 122
# ✅ Page 122 done. Movies collected: 2060
#
# 🔄 Language hi | Page 123
# ✅ Page 123 done. Movies collected: 2077
#
# 🔄 Language hi | Page 124
# ✅ Page 124 done. Movies collected: 2096
#
# 🔄 Language hi | Page 125
# ✅ Page 125 done. Movies collected: 2113
#
# 🔄 Language hi | Page 126
# ✅ Page 126 done. Movies collected: 2130
#
# 🔄 Language hi | Page 127
# ✅ Page 127 done. Movies collected: 2149
#
# 🔄 Language hi | Page 128
# ✅ Page 128 done. Movies collected: 2168
#
# 🔄 Language hi | Page 129
# ✅ Page 129 done. Movies collected: 2186
#
# 🔄 Language hi | Page 130
# ✅ Page 130 done. Movies collected: 2203
#
# 🔄 Language hi | Page 131
# ✅ Page 131 done. Movies collected: 2222
#
# 🔄 Language hi | Page 132
# ✅ Page 132 done. Movies collected: 2240
#
# 🔄 Language hi | Page 133
# ✅ Page 133 done. Movies collected: 2259
#
# 🔄 Language hi | Page 134
# ✅ Page 134 done. Movies collected: 2279
#
# 🔄 Language hi | Page 135
# ✅ Page 135 done. Movies collected: 2297
#
# 🔄 Language hi | Page 136
# ✅ Page 136 done. Movies collected: 2316
#
# 🔄 Language hi | Page 137
# ✅ Page 137 done. Movies collected: 2336
#
# 🔄 Language hi | Page 138
# ✅ Page 138 done. Movies collected: 2352
#
# 🔄 Language hi | Page 139
# ✅ Page 139 done. Movies collected: 2369
#
# 🔄 Language hi | Page 140
# ✅ Page 140 done. Movies collected: 2388
#
# 🔄 Language hi | Page 141
# ✅ Page 141 done. Movies collected: 2408
#
# 🔄 Language hi | Page 142
# ✅ Page 142 done. Movies collected: 2426
#
# 🔄 Language hi | Page 143
# ✅ Page 143 done. Movies collected: 2441
#
# 🔄 Language hi | Page 144
# ✅ Page 144 done. Movies collected: 2457
#
# 🔄 Language hi | Page 145
# ✅ Page 145 done. Movies collected: 2476
#
# 🔄 Language hi | Page 146
# ✅ Page 146 done. Movies collected: 2496
#
# 🔄 Language hi | Page 147
# ✅ Page 147 done. Movies collected: 2513
#
# 🔄 Language hi | Page 148
# ✅ Page 148 done. Movies collected: 2530
#
# 🔄 Language hi | Page 149
# ✅ Page 149 done. Movies collected: 2550
#
# 🔄 Language hi | Page 150
# ✅ Page 150 done. Movies collected: 2570
#
# 🔄 Language hi | Page 151
# ✅ Page 151 done. Movies collected: 2589
#
# 🔄 Language hi | Page 152
# ✅ Page 152 done. Movies collected: 2607
#
# 🔄 Language hi | Page 153
# ✅ Page 153 done. Movies collected: 2624
#
# 🔄 Language hi | Page 154
# ✅ Page 154 done. Movies collected: 2643
#
# 🔄 Language hi | Page 155
# ✅ Page 155 done. Movies collected: 2661
#
# 🔄 Language hi | Page 156
# ✅ Page 156 done. Movies collected: 2679
#
# 🔄 Language hi | Page 157
# ✅ Page 157 done. Movies collected: 2698
#
# 🔄 Language hi | Page 158
# ✅ Page 158 done. Movies collected: 2718
#
# 🔄 Language hi | Page 159
# ✅ Page 159 done. Movies collected: 2737
#
# 🔄 Language hi | Page 160
# ✅ Page 160 done. Movies collected: 2756
#
# 🔄 Language hi | Page 161
# ✅ Page 161 done. Movies collected: 2775
#
# 🔄 Language hi | Page 162
# ✅ Page 162 done. Movies collected: 2794
#
# 🔄 Language hi | Page 163
# ✅ Page 163 done. Movies collected: 2813
#
# 🔄 Language hi | Page 164
# ✅ Page 164 done. Movies collected: 2831
#
# 🔄 Language hi | Page 165
# ✅ Page 165 done. Movies collected: 2850
#
# 🔄 Language hi | Page 166
# ✅ Page 166 done. Movies collected: 2870
#
# 🔄 Language hi | Page 167
# ✅ Page 167 done. Movies collected: 2888
#
# 🔄 Language hi | Page 168
# ✅ Page 168 done. Movies collected: 2908
#
# 🔄 Language hi | Page 169
# ✅ Page 169 done. Movies collected: 2928
#
# 🔄 Language hi | Page 170
# ✅ Page 170 done. Movies collected: 2945
#
# 🔄 Language hi | Page 171
# ✅ Page 171 done. Movies collected: 2962
#
# 🔄 Language hi | Page 172
# ✅ Page 172 done. Movies collected: 2980
#
# 🔄 Language hi | Page 173
# ✅ Page 173 done. Movies collected: 2998
#
# 🔄 Language hi | Page 174
# ✅ Page 174 done. Movies collected: 3017
#
# 🔄 Language hi | Page 175
# ✅ Page 175 done. Movies collected: 3033
#
# 🔄 Language hi | Page 176
# ✅ Page 176 done. Movies collected: 3051
#
# 🔄 Language hi | Page 177
# ✅ Page 177 done. Movies collected: 3069
#
# 🔄 Language hi | Page 178
# ✅ Page 178 done. Movies collected: 3087
#
# 🔄 Language hi | Page 179
# ✅ Page 179 done. Movies collected: 3107
#
# 🔄 Language hi | Page 180
# ✅ Page 180 done. Movies collected: 3123
#
# 🔄 Language hi | Page 181
# ✅ Page 181 done. Movies collected: 3140
#
# 🔄 Language hi | Page 182
# ✅ Page 182 done. Movies collected: 3158
#
# 🔄 Language hi | Page 183
# ✅ Page 183 done. Movies collected: 3176
#
# 🔄 Language hi | Page 184
# ✅ Page 184 done. Movies collected: 3194
#
# 🔄 Language hi | Page 185
# ✅ Page 185 done. Movies collected: 3211
#
# 🔄 Language hi | Page 186
# ✅ Page 186 done. Movies collected: 3229
#
# 🔄 Language hi | Page 187
# ✅ Page 187 done. Movies collected: 3247
#
# 🔄 Language hi | Page 188
# ✅ Page 188 done. Movies collected: 3264
#
# 🔄 Language hi | Page 189
# ✅ Page 189 done. Movies collected: 3282
#
# 🔄 Language hi | Page 190
# ✅ Page 190 done. Movies collected: 3298
#
# 🔄 Language hi | Page 191
# ✅ Page 191 done. Movies collected: 3315
#
# 🔄 Language hi | Page 192
# ✅ Page 192 done. Movies collected: 3332
#
# 🔄 Language hi | Page 193
# ✅ Page 193 done. Movies collected: 3351
#
# 🔄 Language hi | Page 194
# ✅ Page 194 done. Movies collected: 3365
#
# 🔄 Language hi | Page 195
# ✅ Page 195 done. Movies collected: 3382
#
# 🔄 Language hi | Page 196
# ✅ Page 196 done. Movies collected: 3398
#
# 🔄 Language hi | Page 197
# ✅ Page 197 done. Movies collected: 3416
#
# 🔄 Language hi | Page 198
# ✅ Page 198 done. Movies collected: 3434
#
# 🔄 Language hi | Page 199
# ✅ Page 199 done. Movies collected: 3452
#
# 🔄 Language hi | Page 200
# ✅ Page 200 done. Movies collected: 3472
#
# 🔄 Language hi | Page 201
# ✅ Page 201 done. Movies collected: 3491
#
# 🔄 Language hi | Page 202
# ✅ Page 202 done. Movies collected: 3509
#
# 🔄 Language hi | Page 203
# ✅ Page 203 done. Movies collected: 3526
#
# 🔄 Language hi | Page 204
# ✅ Page 204 done. Movies collected: 3545
#
# 🔄 Language hi | Page 205
# ✅ Page 205 done. Movies collected: 3564
#
# 🔄 Language hi | Page 206
# ✅ Page 206 done. Movies collected: 3583
#
# 🔄 Language hi | Page 207
# ✅ Page 207 done. Movies collected: 3601
#
# 🔄 Language hi | Page 208
# ✅ Page 208 done. Movies collected: 3620
#
# 🔄 Language hi | Page 209
# ✅ Page 209 done. Movies collected: 3636
#
# 🔄 Language hi | Page 210
# ✅ Page 210 done. Movies collected: 3654
#
# 🔄 Language hi | Page 211
# ✅ Page 211 done. Movies collected: 3673
#
# 🔄 Language hi | Page 212
# ✅ Page 212 done. Movies collected: 3690
#
# 🔄 Language hi | Page 213
# ✅ Page 213 done. Movies collected: 3708
#
# 🔄 Language hi | Page 214
# ✅ Page 214 done. Movies collected: 3727
#
# 🔄 Language hi | Page 215
# ✅ Page 215 done. Movies collected: 3744
#
# 🔄 Language hi | Page 216
# ✅ Page 216 done. Movies collected: 3764
#
# 🔄 Language hi | Page 217
# ✅ Page 217 done. Movies collected: 3781
#
# 🔄 Language hi | Page 218
# ✅ Page 218 done. Movies collected: 3799
#
# 🔄 Language hi | Page 219
# ✅ Page 219 done. Movies collected: 3816
#
# 🔄 Language hi | Page 220
# ✅ Page 220 done. Movies collected: 3833
#
# 🔄 Language hi | Page 221
# ✅ Page 221 done. Movies collected: 3852
#
# 🔄 Language hi | Page 222
# ✅ Page 222 done. Movies collected: 3871
#
# 🔄 Language hi | Page 223
# ✅ Page 223 done. Movies collected: 3889
#
# 🔄 Language hi | Page 224
# ✅ Page 224 done. Movies collected: 3909
#
# 🔄 Language hi | Page 225
# ✅ Page 225 done. Movies collected: 3928
#
# 🔄 Language hi | Page 226
# ✅ Page 226 done. Movies collected: 3946
#
# 🔄 Language hi | Page 227
# ✅ Page 227 done. Movies collected: 3965
#
# 🔄 Language hi | Page 228
# ✅ Page 228 done. Movies collected: 3982
#
# 🔄 Language hi | Page 229
# ✅ Page 229 done. Movies collected: 4001
#
# 🔄 Language hi | Page 230
# ✅ Page 230 done. Movies collected: 4019
#
# 🔄 Language hi | Page 231
# ✅ Page 231 done. Movies collected: 4036
#
# 🔄 Language hi | Page 232
# ✅ Page 232 done. Movies collected: 4052
#
# 🔄 Language hi | Page 233
# ✅ Page 233 done. Movies collected: 4069
#
# 🔄 Language hi | Page 234
# ✅ Page 234 done. Movies collected: 4087
#
# 🔄 Language hi | Page 235
# ✅ Page 235 done. Movies collected: 4103
#
# 🔄 Language hi | Page 236
# ✅ Page 236 done. Movies collected: 4122
#
# 🔄 Language hi | Page 237
# ✅ Page 237 done. Movies collected: 4138
#
# 🔄 Language hi | Page 238
# ✅ Page 238 done. Movies collected: 4154
#
# 🔄 Language hi | Page 239
# ✅ Page 239 done. Movies collected: 4173
#
# 🔄 Language hi | Page 240
# ✅ Page 240 done. Movies collected: 4190
#
# 🔄 Language hi | Page 241
# ✅ Page 241 done. Movies collected: 4207
#
# 🔄 Language hi | Page 242
# ✅ Page 242 done. Movies collected: 4225
#
# 🔄 Language hi | Page 243
# ✅ Page 243 done. Movies collected: 4245
#
# 🔄 Language hi | Page 244
# ✅ Page 244 done. Movies collected: 4262
#
# 🔄 Language hi | Page 245
# ✅ Page 245 done. Movies collected: 4282
#
# 🔄 Language hi | Page 246
# ✅ Page 246 done. Movies collected: 4296
#
# 🔄 Language hi | Page 247
# ✅ Page 247 done. Movies collected: 4314
#
# 🔄 Language hi | Page 248
# ✅ Page 248 done. Movies collected: 4334
#
# 🔄 Language hi | Page 249
# ✅ Page 249 done. Movies collected: 4354
#
# 🔄 Language hi | Page 250
# ✅ Page 250 done. Movies collected: 4372
#
# 🔄 Language hi | Page 251
# ✅ Page 251 done. Movies collected: 4391
#
# 🔄 Language hi | Page 252
# ✅ Page 252 done. Movies collected: 4409
#
# 🔄 Language hi | Page 253
# ✅ Page 253 done. Movies collected: 4425
#
# 🔄 Language hi | Page 254
# ✅ Page 254 done. Movies collected: 4443
#
# 🔄 Language hi | Page 255
# ✅ Page 255 done. Movies collected: 4461
#
# 🔄 Language hi | Page 256
# ✅ Page 256 done. Movies collected: 4479
#
# 🔄 Language hi | Page 257
# ✅ Page 257 done. Movies collected: 4495
#
# 🔄 Language hi | Page 258
# ✅ Page 258 done. Movies collected: 4514
#
# 🔄 Language hi | Page 259
# ✅ Page 259 done. Movies collected: 4534
#
# 🔄 Language hi | Page 260
# ✅ Page 260 done. Movies collected: 4553
#
# 🔄 Language hi | Page 261
# ✅ Page 261 done. Movies collected: 4570
#
# 🔄 Language hi | Page 262
# ✅ Page 262 done. Movies collected: 4589
#
# 🔄 Language hi | Page 263
# ✅ Page 263 done. Movies collected: 4608
#
# 🔄 Language hi | Page 264
# ✅ Page 264 done. Movies collected: 4626
#
# 🔄 Language hi | Page 265
# ✅ Page 265 done. Movies collected: 4644
#
# 🔄 Language hi | Page 266
# ✅ Page 266 done. Movies collected: 4662
#
# 🔄 Language hi | Page 267
# ✅ Page 267 done. Movies collected: 4680
#
# 🔄 Language hi | Page 268
# ✅ Page 268 done. Movies collected: 4698
#
# 🔄 Language hi | Page 269
# ✅ Page 269 done. Movies collected: 4716
#
# 🔄 Language hi | Page 270
# ✅ Page 270 done. Movies collected: 4733
#
# 🔄 Language hi | Page 271
# ✅ Page 271 done. Movies collected: 4752
#
# 🔄 Language hi | Page 272
# ✅ Page 272 done. Movies collected: 4771
#
# 🔄 Language hi | Page 273
# ✅ Page 273 done. Movies collected: 4791
#
# 🔄 Language hi | Page 274
# ✅ Page 274 done. Movies collected: 4810
#
# 🔄 Language hi | Page 275
# ✅ Page 275 done. Movies collected: 4829
#
# 🔄 Language hi | Page 276
# ✅ Page 276 done. Movies collected: 4848
#
# 🔄 Language hi | Page 277
# ✅ Page 277 done. Movies collected: 4865
#
# 🔄 Language hi | Page 278
# ✅ Page 278 done. Movies collected: 4883
#
# 🔄 Language hi | Page 279
# ✅ Page 279 done. Movies collected: 4900
#
# 🔄 Language hi | Page 280
# ✅ Page 280 done. Movies collected: 4918
#
# 🔄 Language hi | Page 281
# ✅ Page 281 done. Movies collected: 4937
#
# 🔄 Language hi | Page 282
# ✅ Page 282 done. Movies collected: 4955
#
# 🔄 Language hi | Page 283
# ✅ Page 283 done. Movies collected: 4974
#
# 🔄 Language hi | Page 284
# ✅ Page 284 done. Movies collected: 4991
#
# 🔄 Language hi | Page 285
# ✅ Page 285 done. Movies collected: 5008
#
# 🔄 Language hi | Page 286
# ✅ Page 286 done. Movies collected: 5026
#
# 🔄 Language hi | Page 287
# ✅ Page 287 done. Movies collected: 5041
#
# 🔄 Language hi | Page 288
# ✅ Page 288 done. Movies collected: 5059
#
# 🔄 Language hi | Page 289
# ✅ Page 289 done. Movies collected: 5073
#
# 🔄 Language hi | Page 290
# ✅ Page 290 done. Movies collected: 5093
#
# 🔄 Language hi | Page 291
# ✅ Page 291 done. Movies collected: 5109
#
# 🔄 Language hi | Page 292
# ✅ Page 292 done. Movies collected: 5128
#
# 🔄 Language hi | Page 293
# ✅ Page 293 done. Movies collected: 5148
#
# 🔄 Language hi | Page 294
# ✅ Page 294 done. Movies collected: 5167
#
# 🔄 Language hi | Page 295
# ✅ Page 295 done. Movies collected: 5187
#
# 🔄 Language hi | Page 296
# ✅ Page 296 done. Movies collected: 5205
#
# 🔄 Language hi | Page 297
# ✅ Page 297 done. Movies collected: 5224
#
# 🔄 Language hi | Page 298
# ✅ Page 298 done. Movies collected: 5242
#
# 🔄 Language hi | Page 299
# ✅ Page 299 done. Movies collected: 5261
#
# 🔄 Language hi | Page 300
# ✅ Page 300 done. Movies collected: 5281
#
# 🔄 Language hi | Page 301
# ✅ Page 301 done. Movies collected: 5300
#
# 🔄 Language hi | Page 302
# ✅ Page 302 done. Movies collected: 5318
#
# 🔄 Language hi | Page 303
# ✅ Page 303 done. Movies collected: 5338
#
# 🔄 Language hi | Page 304
# ✅ Page 304 done. Movies collected: 5356
#
# 🔄 Language hi | Page 305
# ✅ Page 305 done. Movies collected: 5376
#
# 🔄 Language hi | Page 306
# ✅ Page 306 done. Movies collected: 5395
#
# 🔄 Language hi | Page 307
# ✅ Page 307 done. Movies collected: 5414
#
# 🔄 Language hi | Page 308
# ✅ Page 308 done. Movies collected: 5433
#
# 🔄 Language hi | Page 309
# ✅ Page 309 done. Movies collected: 5453
#
# 🔄 Language hi | Page 310
# ✅ Page 310 done. Movies collected: 5471
#
# 🔄 Language hi | Page 311
# ✅ Page 311 done. Movies collected: 5490
#
# 🔄 Language hi | Page 312
# ✅ Page 312 done. Movies collected: 5509
#
# 🔄 Language hi | Page 313
# ✅ Page 313 done. Movies collected: 5526
#
# 🔄 Language hi | Page 314
# ✅ Page 314 done. Movies collected: 5541
#
# 🔄 Language hi | Page 315
# ✅ Page 315 done. Movies collected: 5561
#
# 🔄 Language hi | Page 316
# ✅ Page 316 done. Movies collected: 5579
#
# 🔄 Language hi | Page 317
# ✅ Page 317 done. Movies collected: 5597
#
# 🔄 Language hi | Page 318
# ✅ Page 318 done. Movies collected: 5617
#
# 🔄 Language hi | Page 319
# ✅ Page 319 done. Movies collected: 5635
#
# 🔄 Language hi | Page 320
# ✅ Page 320 done. Movies collected: 5651
#
# 🔄 Language hi | Page 321
# ✅ Page 321 done. Movies collected: 5669
#
# 🔄 Language hi | Page 322
# ✅ Page 322 done. Movies collected: 5688
#
# 🔄 Language hi | Page 323
# ✅ Page 323 done. Movies collected: 5707
#
# 🔄 Language hi | Page 324
# ✅ Page 324 done. Movies collected: 5723
#
# 🔄 Language hi | Page 325
# ✅ Page 325 done. Movies collected: 5741
#
# 🔄 Language hi | Page 326
# ✅ Page 326 done. Movies collected: 5759
#
# 🔄 Language hi | Page 327
# ✅ Page 327 done. Movies collected: 5776
#
# 🔄 Language hi | Page 328
# ✅ Page 328 done. Movies collected: 5795
#
# 🔄 Language hi | Page 329
# ✅ Page 329 done. Movies collected: 5811
#
# 🔄 Language hi | Page 330
# ✅ Page 330 done. Movies collected: 5830
#
# 🔄 Language hi | Page 331
# ✅ Page 331 done. Movies collected: 5849
#
# 🔄 Language hi | Page 332
# ✅ Page 332 done. Movies collected: 5865
#
# 🔄 Language hi | Page 333
# ✅ Page 333 done. Movies collected: 5881
#
# 🔄 Language hi | Page 334
# ✅ Page 334 done. Movies collected: 5898
#
# 🔄 Language hi | Page 335
# ✅ Page 335 done. Movies collected: 5918
#
# 🔄 Language hi | Page 336
# ✅ Page 336 done. Movies collected: 5938
#
# 🔄 Language hi | Page 337
# ✅ Page 337 done. Movies collected: 5956
#
# 🔄 Language hi | Page 338
# ✅ Page 338 done. Movies collected: 5976
#
# 🔄 Language hi | Page 339
# ✅ Page 339 done. Movies collected: 5993
#
# 🔄 Language hi | Page 340
# ✅ Page 340 done. Movies collected: 6012
#
# 🔄 Language hi | Page 341
# ✅ Page 341 done. Movies collected: 6032
#
# 🔄 Language hi | Page 342
# ✅ Page 342 done. Movies collected: 6049
#
# 🔄 Language hi | Page 343
# ✅ Page 343 done. Movies collected: 6067
#
# 🔄 Language hi | Page 344
# ✅ Page 344 done. Movies collected: 6085
#
# 🔄 Language hi | Page 345
# ✅ Page 345 done. Movies collected: 6103
#
# 🔄 Language hi | Page 346
# ✅ Page 346 done. Movies collected: 6123
#
# 🔄 Language hi | Page 347
# ✅ Page 347 done. Movies collected: 6142
#
# 🔄 Language hi | Page 348
# ✅ Page 348 done. Movies collected: 6161
#
# 🔄 Language hi | Page 349
# ✅ Page 349 done. Movies collected: 6178
#
# 🔄 Language hi | Page 350
# ✅ Page 350 done. Movies collected: 6196
#
# 🔄 Language hi | Page 351
# ✅ Page 351 done. Movies collected: 6214
#
# 🔄 Language hi | Page 352
# ✅ Page 352 done. Movies collected: 6232
#
# 🔄 Language hi | Page 353
# ✅ Page 353 done. Movies collected: 6250
#
# 🔄 Language hi | Page 354
# ✅ Page 354 done. Movies collected: 6267
#
# 🔄 Language hi | Page 355
# ✅ Page 355 done. Movies collected: 6284
#
# 🔄 Language hi | Page 356
# ✅ Page 356 done. Movies collected: 6302
#
# 🔄 Language hi | Page 357
# ✅ Page 357 done. Movies collected: 6321
#
# 🔄 Language hi | Page 358
# ✅ Page 358 done. Movies collected: 6339
#
# 🔄 Language hi | Page 359
# ✅ Page 359 done. Movies collected: 6357
#
# 🔄 Language hi | Page 360
# ✅ Page 360 done. Movies collected: 6376
#
# 🔄 Language hi | Page 361
# ✅ Page 361 done. Movies collected: 6395
#
# 🔄 Language hi | Page 362
# ✅ Page 362 done. Movies collected: 6414
#
# 🔄 Language hi | Page 363
# ✅ Page 363 done. Movies collected: 6432
#
# 🔄 Language hi | Page 364
# ✅ Page 364 done. Movies collected: 6448
#
# 🔄 Language hi | Page 365
# ✅ Page 365 done. Movies collected: 6468
#
# 🔄 Language hi | Page 366
# ✅ Page 366 done. Movies collected: 6486
#
# 🔄 Language hi | Page 367
# ✅ Page 367 done. Movies collected: 6505
#
# 🔄 Language hi | Page 368
# ✅ Page 368 done. Movies collected: 6524
#
# 🔄 Language hi | Page 369
# ✅ Page 369 done. Movies collected: 6542
#
# 🔄 Language hi | Page 370
# ✅ Page 370 done. Movies collected: 6561
#
# 🔄 Language hi | Page 371
# ✅ Page 371 done. Movies collected: 6579
#
# 🔄 Language hi | Page 372
# ✅ Page 372 done. Movies collected: 6598
#
# 🔄 Language hi | Page 373
# ✅ Page 373 done. Movies collected: 6617
#
# 🔄 Language hi | Page 374
# ✅ Page 374 done. Movies collected: 6634
#
# 🔄 Language hi | Page 375
# ✅ Page 375 done. Movies collected: 6653
#
# 🔄 Language hi | Page 376
# ✅ Page 376 done. Movies collected: 6673
#
# 🔄 Language hi | Page 377
# ✅ Page 377 done. Movies collected: 6692
#
# 🔄 Language hi | Page 378
# ✅ Page 378 done. Movies collected: 6711
#
# 🔄 Language hi | Page 379
# ✅ Page 379 done. Movies collected: 6730
#
# 🔄 Language hi | Page 380
# ✅ Page 380 done. Movies collected: 6747
#
# 🔄 Language hi | Page 381
# ✅ Page 381 done. Movies collected: 6767
#
# 🔄 Language hi | Page 382
# ✅ Page 382 done. Movies collected: 6785
#
# 🔄 Language hi | Page 383
# ✅ Page 383 done. Movies collected: 6805
#
# 🔄 Language hi | Page 384
# ✅ Page 384 done. Movies collected: 6822
#
# 🔄 Language hi | Page 385
# ✅ Page 385 done. Movies collected: 6842
#
# 🔄 Language hi | Page 386
# ✅ Page 386 done. Movies collected: 6861
#
# 🔄 Language hi | Page 387
# ✅ Page 387 done. Movies collected: 6879
#
# 🔄 Language hi | Page 388
# ✅ Page 388 done. Movies collected: 6899
#
# 🔄 Language hi | Page 389
# ✅ Page 389 done. Movies collected: 6919
#
# 🔄 Language hi | Page 390
# ✅ Page 390 done. Movies collected: 6938
#
# 🔄 Language hi | Page 391
# ✅ Page 391 done. Movies collected: 6958
#
# 🔄 Language hi | Page 392
# ✅ Page 392 done. Movies collected: 6977
#
# 🔄 Language hi | Page 393
# ✅ Page 393 done. Movies collected: 6995
#
# 🔄 Language hi | Page 394
# ✅ Page 394 done. Movies collected: 7013
#
# 🔄 Language hi | Page 395
# ✅ Page 395 done. Movies collected: 7030
#
# 🔄 Language hi | Page 396
# ✅ Page 396 done. Movies collected: 7049
#
# 🔄 Language hi | Page 397
# ✅ Page 397 done. Movies collected: 7068
#
# 🔄 Language hi | Page 398
# ✅ Page 398 done. Movies collected: 7087
#
# 🔄 Language hi | Page 399
# ✅ Page 399 done. Movies collected: 7106
#
# 🔄 Language hi | Page 400
# ✅ Page 400 done. Movies collected: 7125
#
# 🔄 Language hi | Page 401
# ✅ Page 401 done. Movies collected: 7140
#
# 🔄 Language hi | Page 402
# ✅ Page 402 done. Movies collected: 7158
#
# 🔄 Language hi | Page 403
# ✅ Page 403 done. Movies collected: 7177
#
# 🔄 Language hi | Page 404
# ✅ Page 404 done. Movies collected: 7193
#
# 🔄 Language hi | Page 405
# ✅ Page 405 done. Movies collected: 7212
#
# 🔄 Language hi | Page 406
# ✅ Page 406 done. Movies collected: 7231
#
# 🔄 Language hi | Page 407
# ✅ Page 407 done. Movies collected: 7250
#
# 🔄 Language hi | Page 408
# ✅ Page 408 done. Movies collected: 7270
#
# 🔄 Language hi | Page 409
# ✅ Page 409 done. Movies collected: 7288
#
# 🔄 Language hi | Page 410
# ✅ Page 410 done. Movies collected: 7308
#
# 🔄 Language hi | Page 411
# ✅ Page 411 done. Movies collected: 7327
#
# 🔄 Language hi | Page 412
# ✅ Page 412 done. Movies collected: 7346
#
# 🔄 Language hi | Page 413
# ✅ Page 413 done. Movies collected: 7364
#
# 🔄 Language hi | Page 414
# ✅ Page 414 done. Movies collected: 7382
#
# 🔄 Language hi | Page 415
# ✅ Page 415 done. Movies collected: 7399
#
# 🔄 Language hi | Page 416
# ✅ Page 416 done. Movies collected: 7419
#
# 🔄 Language hi | Page 417
# ✅ Page 417 done. Movies collected: 7432
#
# 🔄 Language hi | Page 418
# ✅ Page 418 done. Movies collected: 7451
#
# 🔄 Language hi | Page 419
# ✅ Page 419 done. Movies collected: 7471
#
# 🔄 Language hi | Page 420
# ✅ Page 420 done. Movies collected: 7489
#
# 🔄 Language hi | Page 421
# ✅ Page 421 done. Movies collected: 7507
#
# 🔄 Language hi | Page 422
# ✅ Page 422 done. Movies collected: 7525
#
# 🔄 Language hi | Page 423
# ✅ Page 423 done. Movies collected: 7543
#
# 🔄 Language hi | Page 424
# ✅ Page 424 done. Movies collected: 7562
#
# 🔄 Language hi | Page 425
# ✅ Page 425 done. Movies collected: 7582
#
# 🔄 Language hi | Page 426
# ✅ Page 426 done. Movies collected: 7601
#
# 🔄 Language hi | Page 427
# ✅ Page 427 done. Movies collected: 7619
#
# 🔄 Language hi | Page 428
# ✅ Page 428 done. Movies collected: 7638
#
# 🔄 Language hi | Page 429
# ✅ Page 429 done. Movies collected: 7657
#
# 🔄 Language hi | Page 430
# ✅ Page 430 done. Movies collected: 7677
#
# 🔄 Language hi | Page 431
# ✅ Page 431 done. Movies collected: 7694
#
# 🔄 Language hi | Page 432
# ✅ Page 432 done. Movies collected: 7713
#
# 🔄 Language hi | Page 433
# ✅ Page 433 done. Movies collected: 7731
#
# 🔄 Language hi | Page 434
# ✅ Page 434 done. Movies collected: 7751
#
# 🔄 Language hi | Page 435
# ✅ Page 435 done. Movies collected: 7771
#
# 🔄 Language hi | Page 436
# ✅ Page 436 done. Movies collected: 7790
#
# 🔄 Language hi | Page 437
# ✅ Page 437 done. Movies collected: 7808
#
# 🔄 Language hi | Page 438
# ✅ Page 438 done. Movies collected: 7826
#
# 🔄 Language hi | Page 439
# ✅ Page 439 done. Movies collected: 7844
#
# 🔄 Language hi | Page 440
# ✅ Page 440 done. Movies collected: 7863
#
# 🔄 Language hi | Page 441
# ✅ Page 441 done. Movies collected: 7868
#
# 🔄 Language hi | Page 442
#
# 🌐 Scraping movies for language: fr
# Fetching genre mapping...
# 🔄 Language fr | Page 1
# ✅ Page 1 done. Movies collected: 0
#
# 🔄 Language fr | Page 2
# ✅ Page 2 done. Movies collected: 2
#
# 🔄 Language fr | Page 3
# ✅ Page 3 done. Movies collected: 2
#
# 🔄 Language fr | Page 4
# ✅ Page 4 done. Movies collected: 2
#
# 🔄 Language fr | Page 5
# ✅ Page 5 done. Movies collected: 4
#
# 🔄 Language fr | Page 6
# ✅ Page 6 done. Movies collected: 4
#
# 🔄 Language fr | Page 7
# ✅ Page 7 done. Movies collected: 5
#
# 🔄 Language fr | Page 8
# ✅ Page 8 done. Movies collected: 5
#
# 🔄 Language fr | Page 9
# ✅ Page 9 done. Movies collected: 5
#
# 🔄 Language fr | Page 10
# ✅ Page 10 done. Movies collected: 5
#
# 🔄 Language fr | Page 11
# ✅ Page 11 done. Movies collected: 12
#
# 🔄 Language fr | Page 12
# ✅ Page 12 done. Movies collected: 20
#
# 🔄 Language fr | Page 13
# ✅ Page 13 done. Movies collected: 27
#
# 🔄 Language fr | Page 14
# ✅ Page 14 done. Movies collected: 29
#
# 🔄 Language fr | Page 15
# ✅ Page 15 done. Movies collected: 43
#
# 🔄 Language fr | Page 16
# ✅ Page 16 done. Movies collected: 58
#
# 🔄 Language fr | Page 17
# ✅ Page 17 done. Movies collected: 73
#
# 🔄 Language fr | Page 18
# ✅ Page 18 done. Movies collected: 88
#
# 🔄 Language fr | Page 19
# ✅ Page 19 done. Movies collected: 104
#
# 🔄 Language fr | Page 20
# ✅ Page 20 done. Movies collected: 120
#
# 🔄 Language fr | Page 21
# ✅ Page 21 done. Movies collected: 138
#
# 🔄 Language fr | Page 22
# ✅ Page 22 done. Movies collected: 155
#
# 🔄 Language fr | Page 23
# ✅ Page 23 done. Movies collected: 173
#
# 🔄 Language fr | Page 24
# ✅ Page 24 done. Movies collected: 190
#
# 🔄 Language fr | Page 25
# ✅ Page 25 done. Movies collected: 208
#
# 🔄 Language fr | Page 26
# ✅ Page 26 done. Movies collected: 223
#
# 🔄 Language fr | Page 27
# ✅ Page 27 done. Movies collected: 243
#
# 🔄 Language fr | Page 28
# ✅ Page 28 done. Movies collected: 263
#
# 🔄 Language fr | Page 29
# ✅ Page 29 done. Movies collected: 282
#
# 🔄 Language fr | Page 30
# ✅ Page 30 done. Movies collected: 301
#
# 🔄 Language fr | Page 31
# ✅ Page 31 done. Movies collected: 318
#
# 🔄 Language fr | Page 32
# ✅ Page 32 done. Movies collected: 335
#
# 🔄 Language fr | Page 33
# ✅ Page 33 done. Movies collected: 353
#
# 🔄 Language fr | Page 34
# ✅ Page 34 done. Movies collected: 372
#
# 🔄 Language fr | Page 35
# ✅ Page 35 done. Movies collected: 392
#
# 🔄 Language fr | Page 36
# ✅ Page 36 done. Movies collected: 411
#
# 🔄 Language fr | Page 37
# ✅ Page 37 done. Movies collected: 431
#
# 🔄 Language fr | Page 38
# ✅ Page 38 done. Movies collected: 450
#
# 🔄 Language fr | Page 39
# ✅ Page 39 done. Movies collected: 468
#
# 🔄 Language fr | Page 40
# ✅ Page 40 done. Movies collected: 485
#
# 🔄 Language fr | Page 41
# ✅ Page 41 done. Movies collected: 504
#
# 🔄 Language fr | Page 42
# ✅ Page 42 done. Movies collected: 523
#
# 🔄 Language fr | Page 43
# ✅ Page 43 done. Movies collected: 543
#
# 🔄 Language fr | Page 44
# ✅ Page 44 done. Movies collected: 562
#
# 🔄 Language fr | Page 45
# ✅ Page 45 done. Movies collected: 581
#
# 🔄 Language fr | Page 46
# ✅ Page 46 done. Movies collected: 599
#
# 🔄 Language fr | Page 47
# ✅ Page 47 done. Movies collected: 615
#
# 🔄 Language fr | Page 48
# ✅ Page 48 done. Movies collected: 635
#
# 🔄 Language fr | Page 49
# ✅ Page 49 done. Movies collected: 655
#
# 🔄 Language fr | Page 50
# ✅ Page 50 done. Movies collected: 675
#
# 🔄 Language fr | Page 51
# ✅ Page 51 done. Movies collected: 694
#
# 🔄 Language fr | Page 52
# ✅ Page 52 done. Movies collected: 710
#
# 🔄 Language fr | Page 53
# ✅ Page 53 done. Movies collected: 729
#
# 🔄 Language fr | Page 54
# ✅ Page 54 done. Movies collected: 749
#
# 🔄 Language fr | Page 55
# ✅ Page 55 done. Movies collected: 768
#
# 🔄 Language fr | Page 56
# ✅ Page 56 done. Movies collected: 787
#
# 🔄 Language fr | Page 57
# ✅ Page 57 done. Movies collected: 806
#
# 🔄 Language fr | Page 58
# ✅ Page 58 done. Movies collected: 823
#
# 🔄 Language fr | Page 59
# ✅ Page 59 done. Movies collected: 842
#
# 🔄 Language fr | Page 60
# ✅ Page 60 done. Movies collected: 860
#
# 🔄 Language fr | Page 61
# ✅ Page 61 done. Movies collected: 878
#
# 🔄 Language fr | Page 62
# ✅ Page 62 done. Movies collected: 898
#
# 🔄 Language fr | Page 63
# ✅ Page 63 done. Movies collected: 917
#
# 🔄 Language fr | Page 64
# ✅ Page 64 done. Movies collected: 937
#
# 🔄 Language fr | Page 65
# ✅ Page 65 done. Movies collected: 955
#
# 🔄 Language fr | Page 66
# ✅ Page 66 done. Movies collected: 975
#
# 🔄 Language fr | Page 67
# ✅ Page 67 done. Movies collected: 994
#
# 🔄 Language fr | Page 68
# ✅ Page 68 done. Movies collected: 1013
#
# 🔄 Language fr | Page 69
# ✅ Page 69 done. Movies collected: 1032
#
# 🔄 Language fr | Page 70
# ✅ Page 70 done. Movies collected: 1051
#
# 🔄 Language fr | Page 71
# ✅ Page 71 done. Movies collected: 1068
#
# 🔄 Language fr | Page 72
# ✅ Page 72 done. Movies collected: 1087
#
# 🔄 Language fr | Page 73
# ✅ Page 73 done. Movies collected: 1107
#
# 🔄 Language fr | Page 74
# ✅ Page 74 done. Movies collected: 1127
#
# 🔄 Language fr | Page 75
# ✅ Page 75 done. Movies collected: 1147
#
# 🔄 Language fr | Page 76
# ✅ Page 76 done. Movies collected: 1163
#
# 🔄 Language fr | Page 77
# ✅ Page 77 done. Movies collected: 1180
#
# 🔄 Language fr | Page 78
# ✅ Page 78 done. Movies collected: 1200
#
# 🔄 Language fr | Page 79
# ✅ Page 79 done. Movies collected: 1218
#
# 🔄 Language fr | Page 80
# ✅ Page 80 done. Movies collected: 1237
#
# 🔄 Language fr | Page 81
# ✅ Page 81 done. Movies collected: 1257
#
# 🔄 Language fr | Page 82
# ✅ Page 82 done. Movies collected: 1276
#
# 🔄 Language fr | Page 83
# ✅ Page 83 done. Movies collected: 1296
#
# 🔄 Language fr | Page 84
# ✅ Page 84 done. Movies collected: 1316
#
# 🔄 Language fr | Page 85
# ✅ Page 85 done. Movies collected: 1334
#
# 🔄 Language fr | Page 86
# ✅ Page 86 done. Movies collected: 1351
#
# 🔄 Language fr | Page 87
# ✅ Page 87 done. Movies collected: 1368
#
# 🔄 Language fr | Page 88
# ✅ Page 88 done. Movies collected: 1387
#
# 🔄 Language fr | Page 89
# ✅ Page 89 done. Movies collected: 1405
#
# 🔄 Language fr | Page 90
# ✅ Page 90 done. Movies collected: 1424
#
# 🔄 Language fr | Page 91
# ✅ Page 91 done. Movies collected: 1443
#
# 🔄 Language fr | Page 92
# ✅ Page 92 done. Movies collected: 1461
#
# 🔄 Language fr | Page 93
# ✅ Page 93 done. Movies collected: 1479
#
# 🔄 Language fr | Page 94
# ✅ Page 94 done. Movies collected: 1495
#
# 🔄 Language fr | Page 95
# ✅ Page 95 done. Movies collected: 1514
#
# 🔄 Language fr | Page 96
# ✅ Page 96 done. Movies collected: 1533
#
# 🔄 Language fr | Page 97
# ✅ Page 97 done. Movies collected: 1553
#
# 🔄 Language fr | Page 98
# ✅ Page 98 done. Movies collected: 1572
#
# 🔄 Language fr | Page 99
# ✅ Page 99 done. Movies collected: 1591
#
# 🔄 Language fr | Page 100
# ✅ Page 100 done. Movies collected: 1611
#
# 🔄 Language fr | Page 101
# ✅ Page 101 done. Movies collected: 1629
#
# 🔄 Language fr | Page 102
# ✅ Page 102 done. Movies collected: 1648
#
# 🔄 Language fr | Page 103
# ✅ Page 103 done. Movies collected: 1667
#
# 🔄 Language fr | Page 104
# ✅ Page 104 done. Movies collected: 1685
#
# 🔄 Language fr | Page 105
# ✅ Page 105 done. Movies collected: 1704
#
# 🔄 Language fr | Page 106
# ✅ Page 106 done. Movies collected: 1723
#
# 🔄 Language fr | Page 107
# ✅ Page 107 done. Movies collected: 1742
#
# 🔄 Language fr | Page 108
# ✅ Page 108 done. Movies collected: 1759
#
# 🔄 Language fr | Page 109
# ✅ Page 109 done. Movies collected: 1778
#
# 🔄 Language fr | Page 110
# ✅ Page 110 done. Movies collected: 1796
#
# 🔄 Language fr | Page 111
# ✅ Page 111 done. Movies collected: 1814
#
# 🔄 Language fr | Page 112
# ✅ Page 112 done. Movies collected: 1834
#
# 🔄 Language fr | Page 113
# ✅ Page 113 done. Movies collected: 1854
#
# 🔄 Language fr | Page 114
# ✅ Page 114 done. Movies collected: 1873
#
# 🔄 Language fr | Page 115
# ✅ Page 115 done. Movies collected: 1893
#
# 🔄 Language fr | Page 116
# ✅ Page 116 done. Movies collected: 1912
#
# 🔄 Language fr | Page 117
# ✅ Page 117 done. Movies collected: 1931
#
# 🔄 Language fr | Page 118
# ✅ Page 118 done. Movies collected: 1949
#
# 🔄 Language fr | Page 119
# ✅ Page 119 done. Movies collected: 1969
#
# 🔄 Language fr | Page 120
# ✅ Page 120 done. Movies collected: 1989
#
# 🔄 Language fr | Page 121
# ✅ Page 121 done. Movies collected: 2008
#
# 🔄 Language fr | Page 122
# ✅ Page 122 done. Movies collected: 2025
#
# 🔄 Language fr | Page 123
# ✅ Page 123 done. Movies collected: 2044
#
# 🔄 Language fr | Page 124
# ✅ Page 124 done. Movies collected: 2062
#
# 🔄 Language fr | Page 125
# ✅ Page 125 done. Movies collected: 2081
#
# 🔄 Language fr | Page 126
# ✅ Page 126 done. Movies collected: 2099
#
# 🔄 Language fr | Page 127
# ✅ Page 127 done. Movies collected: 2118
#
# 🔄 Language fr | Page 128
# ✅ Page 128 done. Movies collected: 2138
#
# 🔄 Language fr | Page 129
# ✅ Page 129 done. Movies collected: 2157
#
# 🔄 Language fr | Page 130
# ✅ Page 130 done. Movies collected: 2177
#
# 🔄 Language fr | Page 131
# ✅ Page 131 done. Movies collected: 2195
#
# 🔄 Language fr | Page 132
# ✅ Page 132 done. Movies collected: 2215
#
# 🔄 Language fr | Page 133
# ✅ Page 133 done. Movies collected: 2233
#
# 🔄 Language fr | Page 134
# ✅ Page 134 done. Movies collected: 2251
#
# 🔄 Language fr | Page 135
# ✅ Page 135 done. Movies collected: 2269
#
# 🔄 Language fr | Page 136
# ✅ Page 136 done. Movies collected: 2289
#
# 🔄 Language fr | Page 137
# ✅ Page 137 done. Movies collected: 2307
#
# 🔄 Language fr | Page 138
# ✅ Page 138 done. Movies collected: 2327
#
# 🔄 Language fr | Page 139
# ✅ Page 139 done. Movies collected: 2344
#
# 🔄 Language fr | Page 140
# ✅ Page 140 done. Movies collected: 2364
#
# 🔄 Language fr | Page 141
# ✅ Page 141 done. Movies collected: 2383
#
# 🔄 Language fr | Page 142
# ✅ Page 142 done. Movies collected: 2402
#
# 🔄 Language fr | Page 143
# ✅ Page 143 done. Movies collected: 2420
#
# 🔄 Language fr | Page 144
# ✅ Page 144 done. Movies collected: 2439
#
# 🔄 Language fr | Page 145
# ✅ Page 145 done. Movies collected: 2457
#
# 🔄 Language fr | Page 146
# ✅ Page 146 done. Movies collected: 2475
#
# 🔄 Language fr | Page 147
# ✅ Page 147 done. Movies collected: 2494
#
# 🔄 Language fr | Page 148
# ✅ Page 148 done. Movies collected: 2512
#
# 🔄 Language fr | Page 149
# ✅ Page 149 done. Movies collected: 2529
#
# 🔄 Language fr | Page 150
# ✅ Page 150 done. Movies collected: 2549
#
# 🔄 Language fr | Page 151
# ✅ Page 151 done. Movies collected: 2569
#
# 🔄 Language fr | Page 152
# ✅ Page 152 done. Movies collected: 2588
#
# 🔄 Language fr | Page 153
# ✅ Page 153 done. Movies collected: 2608
#
# 🔄 Language fr | Page 154
# ✅ Page 154 done. Movies collected: 2627
#
# 🔄 Language fr | Page 155
# ✅ Page 155 done. Movies collected: 2646
#
# 🔄 Language fr | Page 156
# ✅ Page 156 done. Movies collected: 2664
#
# 🔄 Language fr | Page 157
# ✅ Page 157 done. Movies collected: 2682
#
# 🔄 Language fr | Page 158
# ✅ Page 158 done. Movies collected: 2700
#
# 🔄 Language fr | Page 159
# ✅ Page 159 done. Movies collected: 2719
#
# 🔄 Language fr | Page 160
# ✅ Page 160 done. Movies collected: 2739
#
# 🔄 Language fr | Page 161
# ✅ Page 161 done. Movies collected: 2758
#
# 🔄 Language fr | Page 162
# ✅ Page 162 done. Movies collected: 2777
#
# 🔄 Language fr | Page 163
# ✅ Page 163 done. Movies collected: 2797
#
# 🔄 Language fr | Page 164
# ✅ Page 164 done. Movies collected: 2817
#
# 🔄 Language fr | Page 165
# ✅ Page 165 done. Movies collected: 2836
#
# 🔄 Language fr | Page 166
# ✅ Page 166 done. Movies collected: 2856
#
# 🔄 Language fr | Page 167
# ✅ Page 167 done. Movies collected: 2875
#
# 🔄 Language fr | Page 168
# ✅ Page 168 done. Movies collected: 2895
#
# 🔄 Language fr | Page 169
# ✅ Page 169 done. Movies collected: 2912
#
# 🔄 Language fr | Page 170
# ✅ Page 170 done. Movies collected: 2931
#
# 🔄 Language fr | Page 171
# ✅ Page 171 done. Movies collected: 2950
#
# 🔄 Language fr | Page 172
# ✅ Page 172 done. Movies collected: 2969
#
# 🔄 Language fr | Page 173
# ✅ Page 173 done. Movies collected: 2989
#
# 🔄 Language fr | Page 174
# ✅ Page 174 done. Movies collected: 3008
#
# 🔄 Language fr | Page 175
# ✅ Page 175 done. Movies collected: 3027
#
# 🔄 Language fr | Page 176
# ✅ Page 176 done. Movies collected: 3046
#
# 🔄 Language fr | Page 177
# ✅ Page 177 done. Movies collected: 3065
#
# 🔄 Language fr | Page 178
# ✅ Page 178 done. Movies collected: 3084
#
# 🔄 Language fr | Page 179
# ✅ Page 179 done. Movies collected: 3102
#
# 🔄 Language fr | Page 180
# ✅ Page 180 done. Movies collected: 3120
#
# 🔄 Language fr | Page 181
# ✅ Page 181 done. Movies collected: 3139
#
# 🔄 Language fr | Page 182
# ✅ Page 182 done. Movies collected: 3159
#
# 🔄 Language fr | Page 183
# ✅ Page 183 done. Movies collected: 3177
#
# 🔄 Language fr | Page 184
# ✅ Page 184 done. Movies collected: 3194
#
# 🔄 Language fr | Page 185
# ✅ Page 185 done. Movies collected: 3210
#
# 🔄 Language fr | Page 186
# ✅ Page 186 done. Movies collected: 3228
#
# 🔄 Language fr | Page 187
# ✅ Page 187 done. Movies collected: 3248
#
# 🔄 Language fr | Page 188
# ✅ Page 188 done. Movies collected: 3267
#
# 🔄 Language fr | Page 189
# ✅ Page 189 done. Movies collected: 3286
#
# 🔄 Language fr | Page 190
# ✅ Page 190 done. Movies collected: 3302
#
# 🔄 Language fr | Page 191
# ✅ Page 191 done. Movies collected: 3319
#
# 🔄 Language fr | Page 192
# ✅ Page 192 done. Movies collected: 3339
#
# 🔄 Language fr | Page 193
# ✅ Page 193 done. Movies collected: 3355
#
# 🔄 Language fr | Page 194
# ✅ Page 194 done. Movies collected: 3375
#
# 🔄 Language fr | Page 195
# ✅ Page 195 done. Movies collected: 3393
#
# 🔄 Language fr | Page 196
# ✅ Page 196 done. Movies collected: 3412
#
# 🔄 Language fr | Page 197
# ✅ Page 197 done. Movies collected: 3431
#
# 🔄 Language fr | Page 198
# ✅ Page 198 done. Movies collected: 3450
#
# 🔄 Language fr | Page 199
# ✅ Page 199 done. Movies collected: 3470
#
# 🔄 Language fr | Page 200
# ✅ Page 200 done. Movies collected: 3489
#
# 🔄 Language fr | Page 201
# ✅ Page 201 done. Movies collected: 3508
#
# 🔄 Language fr | Page 202
# ✅ Page 202 done. Movies collected: 3527
#
# 🔄 Language fr | Page 203
# ✅ Page 203 done. Movies collected: 3547
#
# 🔄 Language fr | Page 204
# ✅ Page 204 done. Movies collected: 3567
#
# 🔄 Language fr | Page 205
# ✅ Page 205 done. Movies collected: 3584
#
# 🔄 Language fr | Page 206
# ✅ Page 206 done. Movies collected: 3604
#
# 🔄 Language fr | Page 207
# ✅ Page 207 done. Movies collected: 3623
#
# 🔄 Language fr | Page 208
# ✅ Page 208 done. Movies collected: 3642
#
# 🔄 Language fr | Page 209
# ✅ Page 209 done. Movies collected: 3662
#
# 🔄 Language fr | Page 210
# ✅ Page 210 done. Movies collected: 3681
#
# 🔄 Language fr | Page 211
# ✅ Page 211 done. Movies collected: 3701
#
# 🔄 Language fr | Page 212
# ✅ Page 212 done. Movies collected: 3721
#
# 🔄 Language fr | Page 213
# ✅ Page 213 done. Movies collected: 3741
#
# 🔄 Language fr | Page 214
# ✅ Page 214 done. Movies collected: 3760
#
# 🔄 Language fr | Page 215
# ✅ Page 215 done. Movies collected: 3779
#
# 🔄 Language fr | Page 216
# ✅ Page 216 done. Movies collected: 3799
#
# 🔄 Language fr | Page 217
# ✅ Page 217 done. Movies collected: 3814
#
# 🔄 Language fr | Page 218
# ✅ Page 218 done. Movies collected: 3832
#
# 🔄 Language fr | Page 219
# ✅ Page 219 done. Movies collected: 3852
#
# 🔄 Language fr | Page 220
# ✅ Page 220 done. Movies collected: 3870
#
# 🔄 Language fr | Page 221
# ✅ Page 221 done. Movies collected: 3890
#
# 🔄 Language fr | Page 222
# ✅ Page 222 done. Movies collected: 3909
#
# 🔄 Language fr | Page 223
# ✅ Page 223 done. Movies collected: 3927
#
# 🔄 Language fr | Page 224
# ✅ Page 224 done. Movies collected: 3946
#
# 🔄 Language fr | Page 225
# ✅ Page 225 done. Movies collected: 3963
#
# 🔄 Language fr | Page 226
# ✅ Page 226 done. Movies collected: 3983
#
# 🔄 Language fr | Page 227
# ✅ Page 227 done. Movies collected: 4002
#
# 🔄 Language fr | Page 228
# ✅ Page 228 done. Movies collected: 4021
#
# 🔄 Language fr | Page 229
# ✅ Page 229 done. Movies collected: 4041
#
# 🔄 Language fr | Page 230
# ✅ Page 230 done. Movies collected: 4060
#
# 🔄 Language fr | Page 231
# ✅ Page 231 done. Movies collected: 4079
#
# 🔄 Language fr | Page 232
# ✅ Page 232 done. Movies collected: 4097
#
# 🔄 Language fr | Page 233
# ✅ Page 233 done. Movies collected: 4117
#
# 🔄 Language fr | Page 234
# ✅ Page 234 done. Movies collected: 4137
#
# 🔄 Language fr | Page 235
# ✅ Page 235 done. Movies collected: 4155
#
# 🔄 Language fr | Page 236
# ✅ Page 236 done. Movies collected: 4174
#
# 🔄 Language fr | Page 237
# ✅ Page 237 done. Movies collected: 4193
#
# 🔄 Language fr | Page 238
# ✅ Page 238 done. Movies collected: 4211
#
# 🔄 Language fr | Page 239
# ✅ Page 239 done. Movies collected: 4231
#
# 🔄 Language fr | Page 240
# ✅ Page 240 done. Movies collected: 4251
#
# 🔄 Language fr | Page 241
# ✅ Page 241 done. Movies collected: 4271
#
# 🔄 Language fr | Page 242
# ✅ Page 242 done. Movies collected: 4290
#
# 🔄 Language fr | Page 243
# ✅ Page 243 done. Movies collected: 4307
#
# 🔄 Language fr | Page 244
# ✅ Page 244 done. Movies collected: 4322
#
# 🔄 Language fr | Page 245
# ✅ Page 245 done. Movies collected: 4341
#
# 🔄 Language fr | Page 246
# ✅ Page 246 done. Movies collected: 4360
#
# 🔄 Language fr | Page 247
# ✅ Page 247 done. Movies collected: 4378
#
# 🔄 Language fr | Page 248
# ✅ Page 248 done. Movies collected: 4395
#
# 🔄 Language fr | Page 249
# ✅ Page 249 done. Movies collected: 4412
#
# 🔄 Language fr | Page 250
# ✅ Page 250 done. Movies collected: 4432
#
# 🔄 Language fr | Page 251
# ✅ Page 251 done. Movies collected: 4452
#
# 🔄 Language fr | Page 252
# ✅ Page 252 done. Movies collected: 4471
#
# 🔄 Language fr | Page 253
# ✅ Page 253 done. Movies collected: 4488
#
# 🔄 Language fr | Page 254
# ✅ Page 254 done. Movies collected: 4506
#
# 🔄 Language fr | Page 255
# ✅ Page 255 done. Movies collected: 4522
#
# 🔄 Language fr | Page 256
# ✅ Page 256 done. Movies collected: 4539
#
# 🔄 Language fr | Page 257
# ✅ Page 257 done. Movies collected: 4559
#
# 🔄 Language fr | Page 258
# ✅ Page 258 done. Movies collected: 4578
#
# 🔄 Language fr | Page 259
# ✅ Page 259 done. Movies collected: 4596
#
# 🔄 Language fr | Page 260
# ✅ Page 260 done. Movies collected: 4614
#
# 🔄 Language fr | Page 261
# ✅ Page 261 done. Movies collected: 4633
#
# 🔄 Language fr | Page 262
# ✅ Page 262 done. Movies collected: 4652
#
# 🔄 Language fr | Page 263
# ✅ Page 263 done. Movies collected: 4670
#
# 🔄 Language fr | Page 264
# ✅ Page 264 done. Movies collected: 4688
#
# 🔄 Language fr | Page 265
# ✅ Page 265 done. Movies collected: 4705
#
# 🔄 Language fr | Page 266
# ✅ Page 266 done. Movies collected: 4724
#
# 🔄 Language fr | Page 267
# ✅ Page 267 done. Movies collected: 4743
#
# 🔄 Language fr | Page 268
# ✅ Page 268 done. Movies collected: 4762
#
# 🔄 Language fr | Page 269
# ✅ Page 269 done. Movies collected: 4782
#
# 🔄 Language fr | Page 270
# ✅ Page 270 done. Movies collected: 4801
#
# 🔄 Language fr | Page 271
# ✅ Page 271 done. Movies collected: 4821
#
# 🔄 Language fr | Page 272
# ✅ Page 272 done. Movies collected: 4837
#
# 🔄 Language fr | Page 273
# ✅ Page 273 done. Movies collected: 4855
#
# 🔄 Language fr | Page 274
# ✅ Page 274 done. Movies collected: 4873
#
# 🔄 Language fr | Page 275
# ✅ Page 275 done. Movies collected: 4890
#
# 🔄 Language fr | Page 276
# ✅ Page 276 done. Movies collected: 4909
#
# 🔄 Language fr | Page 277
# ✅ Page 277 done. Movies collected: 4926
#
# 🔄 Language fr | Page 278
# ✅ Page 278 done. Movies collected: 4945
#
# 🔄 Language fr | Page 279
# ✅ Page 279 done. Movies collected: 4965
#
# 🔄 Language fr | Page 280
# ✅ Page 280 done. Movies collected: 4984
#
# 🔄 Language fr | Page 281
# ✅ Page 281 done. Movies collected: 5002
#
# 🔄 Language fr | Page 282
# ✅ Page 282 done. Movies collected: 5020
#
# 🔄 Language fr | Page 283
# ✅ Page 283 done. Movies collected: 5038
#
# 🔄 Language fr | Page 284
# ✅ Page 284 done. Movies collected: 5057
#
# 🔄 Language fr | Page 285
# ✅ Page 285 done. Movies collected: 5076
#
# 🔄 Language fr | Page 286
# ✅ Page 286 done. Movies collected: 5095
#
# 🔄 Language fr | Page 287
# ✅ Page 287 done. Movies collected: 5114
#
# 🔄 Language fr | Page 288
# ✅ Page 288 done. Movies collected: 5133
#
# 🔄 Language fr | Page 289
# ✅ Page 289 done. Movies collected: 5153
#
# 🔄 Language fr | Page 290
# ✅ Page 290 done. Movies collected: 5169
#
# 🔄 Language fr | Page 291
# ✅ Page 291 done. Movies collected: 5188
#
# 🔄 Language fr | Page 292
# ✅ Page 292 done. Movies collected: 5207
#
# 🔄 Language fr | Page 293
# ...
# ✅ Page 259 done. Movies collected: 4723
#
# 🔄 Language pt | Page 260
# ✅ Page 260 done. Movies collected: 4741
#
# 🔄 Language pt | Page 261
# ✅ Page 261 done. Movies collected: 4758
#
# 🔄 Language pt | Page 262
# ✅ Page 262 done. Movies collected: 4776
#
# 🔄 Language pt | Page 263
# ✅ Page 263 done. Movies collected: 4795
#
# 🔄 Language pt | Page 264
# ✅ Page 264 done. Movies collected: 4815
#
# 🔄 Language pt | Page 265
# ✅ Page 265 done. Movies collected: 4834
#
# 🔄 Language pt | Page 266
# ✅ Page 266 done. Movies collected: 4851
#
# 🔄 Language pt | Page 267
# ✅ Page 267 done. Movies collected: 4870
#
# 🔄 Language pt | Page 268
# ✅ Page 268 done. Movies collected: 4887
#
# 🔄 Language pt | Page 269
# ✅ Page 269 done. Movies collected: 4906
#
# 🔄 Language pt | Page 270
# ✅ Page 270 done. Movies collected: 4925
#
# 🔄 Language pt | Page 271
# ✅ Page 271 done. Movies collected: 4945
#
# 🔄 Language pt | Page 272
# ✅ Page 272 done. Movies collected: 4964
#
# 🔄 Language pt | Page 273
# ✅ Page 273 done. Movies collected: 4981
#
# 🔄 Language pt | Page 274
# ✅ Page 274 done. Movies collected: 4999
#
# 🔄 Language pt | Page 275
# ✅ Page 275 done. Movies collected: 5018
#
# 🔄 Language pt | Page 276
# ✅ Page 276 done. Movies collected: 5036
#
# 🔄 Language pt | Page 277
# ✅ Page 277 done. Movies collected: 5056
#
# 🔄 Language pt | Page 278
# ✅ Page 278 done. Movies collected: 5075
#
# 🔄 Language pt | Page 279
# ✅ Page 279 done. Movies collected: 5092
#
# 🔄 Language pt | Page 280
# ✅ Page 280 done. Movies collected: 5112
#
# 🔄 Language pt | Page 281
# ✅ Page 281 done. Movies collected: 5131
#
# 🔄 Language pt | Page 282
# ✅ Page 282 done. Movies collected: 5149
#
# 🔄 Language pt | Page 283
# ✅ Page 283 done. Movies collected: 5167
#
# 🔄 Language pt | Page 284
# ✅ Page 284 done. Movies collected: 5187
#
# 🔄 Language pt | Page 285
# ✅ Page 285 done. Movies collected: 5205
#
# 🔄 Language pt | Page 286
# ✅ Page 286 done. Movies collected: 5221
#
# 🔄 Language pt | Page 287
# ✅ Page 287 done. Movies collected: 5240
#
# 🔄 Language pt | Page 288
# ✅ Page 288 done. Movies collected: 5259
#
# 🔄 Language pt | Page 289
# ✅ Page 289 done. Movies collected: 5278
#
# 🔄 Language pt | Page 290
# ✅ Page 290 done. Movies collected: 5297
#
# 🔄 Language pt | Page 291
# ✅ Page 291 done. Movies collected: 5316
#
# 🔄 Language pt | Page 292
# ✅ Page 292 done. Movies collected: 5336
#
# 🔄 Language pt | Page 293
# ✅ Page 293 done. Movies collected: 5352
#
# 🔄 Language pt | Page 294
# ✅ Page 294 done. Movies collected: 5371
#
# 🔄 Language pt | Page 295
# ✅ Page 295 done. Movies collected: 5391
#
# 🔄 Language pt | Page 296
# ✅ Page 296 done. Movies collected: 5408
#
# 🔄 Language pt | Page 297
# ✅ Page 297 done. Movies collected: 5427
#
# 🔄 Language pt | Page 298
# ✅ Page 298 done. Movies collected: 5446
#
# 🔄 Language pt | Page 299
# ✅ Page 299 done. Movies collected: 5464
#
# 🔄 Language pt | Page 300
# ✅ Page 300 done. Movies collected: 5482
#
# 🔄 Language pt | Page 301
# ✅ Page 301 done. Movies collected: 5502
#
# 🔄 Language pt | Page 302
# ✅ Page 302 done. Movies collected: 5521
#
# 🔄 Language pt | Page 303
# ✅ Page 303 done. Movies collected: 5540
#
# 🔄 Language pt | Page 304
# ✅ Page 304 done. Movies collected: 5560
#
# 🔄 Language pt | Page 305
# ✅ Page 305 done. Movies collected: 5579
#
# 🔄 Language pt | Page 306
# ✅ Page 306 done. Movies collected: 5598
#
# 🔄 Language pt | Page 307
# ✅ Page 307 done. Movies collected: 5617
#
# 🔄 Language pt | Page 308
# ✅ Page 308 done. Movies collected: 5637
#
# 🔄 Language pt | Page 309
# ✅ Page 309 done. Movies collected: 5656
#
# 🔄 Language pt | Page 310
# ✅ Page 310 done. Movies collected: 5674
#
# 🔄 Language pt | Page 311
# ✅ Page 311 done. Movies collected: 5693
#
# 🔄 Language pt | Page 312
# ✅ Page 312 done. Movies collected: 5712
#
# 🔄 Language pt | Page 313
# ✅ Page 313 done. Movies collected: 5730
#
# 🔄 Language pt | Page 314
# ✅ Page 314 done. Movies collected: 5750
#
# 🔄 Language pt | Page 315
# ✅ Page 315 done. Movies collected: 5769
#
# 🔄 Language pt | Page 316
# ✅ Page 316 done. Movies collected: 5789
#
# 🔄 Language pt | Page 317
# ✅ Page 317 done. Movies collected: 5807
#
# 🔄 Language pt | Page 318
# ✅ Page 318 done. Movies collected: 5825
#
# 🔄 Language pt | Page 319
# ✅ Page 319 done. Movies collected: 5842
#
# 🔄 Language pt | Page 320
# ✅ Page 320 done. Movies collected: 5862
#
# 🔄 Language pt | Page 321
# ✅ Page 321 done. Movies collected: 5881
#
# 🔄 Language pt | Page 322
# ✅ Page 322 done. Movies collected: 5898
#
# 🔄 Language pt | Page 323
# ✅ Page 323 done. Movies collected: 5918
#
# 🔄 Language pt | Page 324
# ✅ Page 324 done. Movies collected: 5937
#
# 🔄 Language pt | Page 325
# ✅ Page 325 done. Movies collected: 5956
#
# 🔄 Language pt | Page 326
# ✅ Page 326 done. Movies collected: 5974
#
# 🔄 Language pt | Page 327
# ✅ Page 327 done. Movies collected: 5993
#
# 🔄 Language pt | Page 328
# ✅ Page 328 done. Movies collected: 6010
#
# 🔄 Language pt | Page 329
# ✅ Page 329 done. Movies collected: 6030
#
# 🔄 Language pt | Page 330
# ✅ Page 330 done. Movies collected: 6048
#
# 🔄 Language pt | Page 331
# ✅ Page 331 done. Movies collected: 6068
#
# 🔄 Language pt | Page 332
# ✅ Page 332 done. Movies collected: 6088
#
# 🔄 Language pt | Page 333
# ✅ Page 333 done. Movies collected: 6108
#
# 🔄 Language pt | Page 334
# ✅ Page 334 done. Movies collected: 6127
#
# 🔄 Language pt | Page 335
# ✅ Page 335 done. Movies collected: 6144
#
# 🔄 Language pt | Page 336
# ✅ Page 336 done. Movies collected: 6163
#
# 🔄 Language pt | Page 337
# ✅ Page 337 done. Movies collected: 6183
#
# 🔄 Language pt | Page 338
# ✅ Page 338 done. Movies collected: 6200
#
# 🔄 Language pt | Page 339
# ✅ Page 339 done. Movies collected: 6219
#
# 🔄 Language pt | Page 340
# ✅ Page 340 done. Movies collected: 6239
#
# 🔄 Language pt | Page 341
# ✅ Page 341 done. Movies collected: 6256
#
# 🔄 Language pt | Page 342
# ✅ Page 342 done. Movies collected: 6275
#
# 🔄 Language pt | Page 343
# ✅ Page 343 done. Movies collected: 6292
#
# 🔄 Language pt | Page 344
# ✅ Page 344 done. Movies collected: 6311
#
# 🔄 Language pt | Page 345
# ✅ Page 345 done. Movies collected: 6329
#
# 🔄 Language pt | Page 346
# ✅ Page 346 done. Movies collected: 6347
#
# 🔄 Language pt | Page 347
# ✅ Page 347 done. Movies collected: 6365
#
# 🔄 Language pt | Page 348
# ✅ Page 348 done. Movies collected: 6384
#
# 🔄 Language pt | Page 349
# ✅ Page 349 done. Movies collected: 6403
#
# 🔄 Language pt | Page 350
# ✅ Page 350 done. Movies collected: 6419
#
# 🔄 Language pt | Page 351
# ✅ Page 351 done. Movies collected: 6438
#
# 🔄 Language pt | Page 352
# ✅ Page 352 done. Movies collected: 6457
#
# 🔄 Language pt | Page 353
# ✅ Page 353 done. Movies collected: 6474
#
# 🔄 Language pt | Page 354
# ✅ Page 354 done. Movies collected: 6492
#
# 🔄 Language pt | Page 355
# ✅ Page 355 done. Movies collected: 6511
#
# 🔄 Language pt | Page 356
# ✅ Page 356 done. Movies collected: 6530
#
# 🔄 Language pt | Page 357
# ✅ Page 357 done. Movies collected: 6549
#
# 🔄 Language pt | Page 358
# ✅ Page 358 done. Movies collected: 6568
#
# 🔄 Language pt | Page 359
# ✅ Page 359 done. Movies collected: 6586
#
# 🔄 Language pt | Page 360
# ✅ Page 360 done. Movies collected: 6605
#
# 🔄 Language pt | Page 361
# ✅ Page 361 done. Movies collected: 6623
#
# 🔄 Language pt | Page 362
# ✅ Page 362 done. Movies collected: 6642
#
# 🔄 Language pt | Page 363
# ✅ Page 363 done. Movies collected: 6661
#
# 🔄 Language pt | Page 364
# ✅ Page 364 done. Movies collected: 6679
#
# 🔄 Language pt | Page 365
# ✅ Page 365 done. Movies collected: 6698
#
# 🔄 Language pt | Page 366
# ✅ Page 366 done. Movies collected: 6716
#
# 🔄 Language pt | Page 367
# ✅ Page 367 done. Movies collected: 6735
#
# 🔄 Language pt | Page 368
# ✅ Page 368 done. Movies collected: 6753
#
# 🔄 Language pt | Page 369
# ✅ Page 369 done. Movies collected: 6772
#
# 🔄 Language pt | Page 370
# ✅ Page 370 done. Movies collected: 6792
#
# 🔄 Language pt | Page 371
# ✅ Page 371 done. Movies collected: 6811
#
# 🔄 Language pt | Page 372
# ✅ Page 372 done. Movies collected: 6829
#
# 🔄 Language pt | Page 373
# ✅ Page 373 done. Movies collected: 6848
#
# 🔄 Language pt | Page 374
# ✅ Page 374 done. Movies collected: 6865
#
# 🔄 Language pt | Page 375
# ✅ Page 375 done. Movies collected: 6882
#
# 🔄 Language pt | Page 376
# ✅ Page 376 done. Movies collected: 6900
#
# 🔄 Language pt | Page 377
# ✅ Page 377 done. Movies collected: 6918
#
# 🔄 Language pt | Page 378
# ✅ Page 378 done. Movies collected: 6938
#
# 🔄 Language pt | Page 379
# ✅ Page 379 done. Movies collected: 6955
#
# 🔄 Language pt | Page 380
# ✅ Page 380 done. Movies collected: 6970
#
# 🔄 Language pt | Page 381
# ✅ Page 381 done. Movies collected: 6989
#
# 🔄 Language pt | Page 382
# ✅ Page 382 done. Movies collected: 7008
#
# 🔄 Language pt | Page 383
# ✅ Page 383 done. Movies collected: 7026
#
# 🔄 Language pt | Page 384
# ✅ Page 384 done. Movies collected: 7044
#
# 🔄 Language pt | Page 385
# ✅ Page 385 done. Movies collected: 7063
#
# 🔄 Language pt | Page 386
# ✅ Page 386 done. Movies collected: 7083
#
# 🔄 Language pt | Page 387
# ✅ Page 387 done. Movies collected: 7102
#
# 🔄 Language pt | Page 388
# ✅ Page 388 done. Movies collected: 7122
#
# 🔄 Language pt | Page 389
# ✅ Page 389 done. Movies collected: 7141
#
# 🔄 Language pt | Page 390
# ✅ Page 390 done. Movies collected: 7159
#
# 🔄 Language pt | Page 391
# ✅ Page 391 done. Movies collected: 7177
#
# 🔄 Language pt | Page 392
# ✅ Page 392 done. Movies collected: 7197
#
# 🔄 Language pt | Page 393
# ✅ Page 393 done. Movies collected: 7216
#
# 🔄 Language pt | Page 394
# ✅ Page 394 done. Movies collected: 7236
#
# 🔄 Language pt | Page 395
# ✅ Page 395 done. Movies collected: 7256
#
# 🔄 Language pt | Page 396
# ✅ Page 396 done. Movies collected: 7274
#
# 🔄 Language pt | Page 397
# ✅ Page 397 done. Movies collected: 7293
#
# 🔄 Language pt | Page 398
# ✅ Page 398 done. Movies collected: 7311
#
# 🔄 Language pt | Page 399
# ✅ Page 399 done. Movies collected: 7329
#
# 🔄 Language pt | Page 400
# ✅ Page 400 done. Movies collected: 7346
#
# 🔄 Language pt | Page 401
# ✅ Page 401 done. Movies collected: 7366
#
# 🔄 Language pt | Page 402
# ✅ Page 402 done. Movies collected: 7384
#
# 🔄 Language pt | Page 403
# ✅ Page 403 done. Movies collected: 7404
#
# 🔄 Language pt | Page 404
# ✅ Page 404 done. Movies collected: 7424
#
# 🔄 Language pt | Page 405
# ✅ Page 405 done. Movies collected: 7442
#
# 🔄 Language pt | Page 406
# ✅ Page 406 done. Movies collected: 7461
#
# 🔄 Language pt | Page 407
# ✅ Page 407 done. Movies collected: 7480
#
# 🔄 Language pt | Page 408
# ✅ Page 408 done. Movies collected: 7498
#
# 🔄 Language pt | Page 409
# ✅ Page 409 done. Movies collected: 7515
#
# 🔄 Language pt | Page 410
# ✅ Page 410 done. Movies collected: 7533
#
# 🔄 Language pt | Page 411
# ✅ Page 411 done. Movies collected: 7552
#
# 🔄 Language pt | Page 412
# ✅ Page 412 done. Movies collected: 7572
#
# 🔄 Language pt | Page 413
# ✅ Page 413 done. Movies collected: 7591
#
# 🔄 Language pt | Page 414
# ✅ Page 414 done. Movies collected: 7609
#
# 🔄 Language pt | Page 415
# ✅ Page 415 done. Movies collected: 7629
#
# 🔄 Language pt | Page 416
# ✅ Page 416 done. Movies collected: 7646
#
# 🔄 Language pt | Page 417
# ✅ Page 417 done. Movies collected: 7665
#
# 🔄 Language pt | Page 418
# ✅ Page 418 done. Movies collected: 7683
#
# 🔄 Language pt | Page 419
# ✅ Page 419 done. Movies collected: 7700
#
# 🔄 Language pt | Page 420
# ✅ Page 420 done. Movies collected: 7719
#
# 🔄 Language pt | Page 421
# ✅ Page 421 done. Movies collected: 7737
#
# 🔄 Language pt | Page 422
# ✅ Page 422 done. Movies collected: 7757
#
# 🔄 Language pt | Page 423
# ✅ Page 423 done. Movies collected: 7777
#
# 🔄 Language pt | Page 424
# ✅ Page 424 done. Movies collected: 7795
#
# 🔄 Language pt | Page 425
# ✅ Page 425 done. Movies collected: 7812
#
# 🔄 Language pt | Page 426
# ✅ Page 426 done. Movies collected: 7831
#
# 🔄 Language pt | Page 427
# ✅ Page 427 done. Movies collected: 7850
#
# 🔄 Language pt | Page 428
# ✅ Page 428 done. Movies collected: 7870
#
# 🔄 Language pt | Page 429
# ✅ Page 429 done. Movies collected: 7890
#
# 🔄 Language pt | Page 430
# ✅ Page 430 done. Movies collected: 7909
#
# 🔄 Language pt | Page 431
# ✅ Page 431 done. Movies collected: 7928
#
# 🔄 Language pt | Page 432
# ✅ Page 432 done. Movies collected: 7947
#
# 🔄 Language pt | Page 433
# ✅ Page 433 done. Movies collected: 7965
#
# 🔄 Language pt | Page 434
# ✅ Page 434 done. Movies collected: 7985
#
# 🔄 Language pt | Page 435
# ✅ Page 435 done. Movies collected: 8003
#
# 🔄 Language pt | Page 436
# ✅ Page 436 done. Movies collected: 8022
#
# 🔄 Language pt | Page 437
# ✅ Page 437 done. Movies collected: 8042
#
# 🔄 Language pt | Page 438
# ✅ Page 438 done. Movies collected: 8061
#
# 🔄 Language pt | Page 439
# ✅ Page 439 done. Movies collected: 8080
#
# 🔄 Language pt | Page 440
# ✅ Page 440 done. Movies collected: 8098
#
# 🔄 Language pt | Page 441
# ✅ Page 441 done. Movies collected: 8116
#
# 🔄 Language pt | Page 442
# ✅ Page 442 done. Movies collected: 8135
#
# 🔄 Language pt | Page 443
# ✅ Page 443 done. Movies collected: 8153
#
# 🔄 Language pt | Page 444
# ✅ Page 444 done. Movies collected: 8172
#
# 🔄 Language pt | Page 445
# ✅ Page 445 done. Movies collected: 8190
#
# 🔄 Language pt | Page 446
# ✅ Page 446 done. Movies collected: 8206
#
# 🔄 Language pt | Page 447
# ✅ Page 447 done. Movies collected: 8224
#
# 🔄 Language pt | Page 448
# ✅ Page 448 done. Movies collected: 8243
#
# 🔄 Language pt | Page 449
# ✅ Page 449 done. Movies collected: 8261
#
# 🔄 Language pt | Page 450
# ✅ Page 450 done. Movies collected: 8280
#
# 🔄 Language pt | Page 451
# ✅ Page 451 done. Movies collected: 8300
#
# 🔄 Language pt | Page 452
# ✅ Page 452 done. Movies collected: 8318
#
# 🔄 Language pt | Page 453
# ✅ Page 453 done. Movies collected: 8335
#
# 🔄 Language pt | Page 454
# ✅ Page 454 done. Movies collected: 8353
#
# 🔄 Language pt | Page 455
# ✅ Page 455 done. Movies collected: 8371
#
# 🔄 Language pt | Page 456
# ✅ Page 456 done. Movies collected: 8389
#
# 🔄 Language pt | Page 457
# ✅ Page 457 done. Movies collected: 8407
#
# 🔄 Language pt | Page 458
# ✅ Page 458 done. Movies collected: 8425
#
# 🔄 Language pt | Page 459
# ✅ Page 459 done. Movies collected: 8444
#
# 🔄 Language pt | Page 460
# ✅ Page 460 done. Movies collected: 8460
#
# 🔄 Language pt | Page 461
# ✅ Page 461 done. Movies collected: 8478
#
# 🔄 Language pt | Page 462
# ✅ Page 462 done. Movies collected: 8497
#
# 🔄 Language pt | Page 463
# ✅ Page 463 done. Movies collected: 8516
#
# 🔄 Language pt | Page 464
# ✅ Page 464 done. Movies collected: 8534
#
# 🔄 Language pt | Page 465
# ✅ Page 465 done. Movies collected: 8554
#
# 🔄 Language pt | Page 466
# ✅ Page 466 done. Movies collected: 8574
#
# 🔄 Language pt | Page 467
# ✅ Page 467 done. Movies collected: 8591
#
# 🔄 Language pt | Page 468
# ✅ Page 468 done. Movies collected: 8607
#
# 🔄 Language pt | Page 469
# ✅ Page 469 done. Movies collected: 8626
#
# 🔄 Language pt | Page 470
# ✅ Page 470 done. Movies collected: 8645
#
# 🔄 Language pt | Page 471
# ✅ Page 471 done. Movies collected: 8665
#
# 🔄 Language pt | Page 472
# ✅ Page 472 done. Movies collected: 8685
#
# 🔄 Language pt | Page 473
# ✅ Page 473 done. Movies collected: 8704
#
# 🔄 Language pt | Page 474
# ✅ Page 474 done. Movies collected: 8723
#
# 🔄 Language pt | Page 475
# ✅ Page 475 done. Movies collected: 8742
#
# 🔄 Language pt | Page 476
# ✅ Page 476 done. Movies collected: 8761
#
# 🔄 Language pt | Page 477
# ✅ Page 477 done. Movies collected: 8780
#
# 🔄 Language pt | Page 478
# ✅ Page 478 done. Movies collected: 8799
#
# 🔄 Language pt | Page 479
# ✅ Page 479 done. Movies collected: 8818
#
# 🔄 Language pt | Page 480
# ✅ Page 480 done. Movies collected: 8837
#
# 🔄 Language pt | Page 481
# ✅ Page 481 done. Movies collected: 8855
#
# 🔄 Language pt | Page 482
# ✅ Page 482 done. Movies collected: 8873
#
# 🔄 Language pt | Page 483
# ✅ Page 483 done. Movies collected: 8891
#
# 🔄 Language pt | Page 484
# ✅ Page 484 done. Movies collected: 8911
#
# 🔄 Language pt | Page 485
# ✅ Page 485 done. Movies collected: 8931
#
# 🔄 Language pt | Page 486
# ✅ Page 486 done. Movies collected: 8951
#
# 🔄 Language pt | Page 487
# ✅ Page 487 done. Movies collected: 8970
#
# 🔄 Language pt | Page 488
# ✅ Page 488 done. Movies collected: 8988
#
# 🔄 Language pt | Page 489
# ✅ Page 489 done. Movies collected: 9007
#
# 🔄 Language pt | Page 490
# ✅ Page 490 done. Movies collected: 9026
#
# 🔄 Language pt | Page 491
# ✅ Page 491 done. Movies collected: 9045
#
# 🔄 Language pt | Page 492
# ✅ Page 492 done. Movies collected: 9063
#
# 🔄 Language pt | Page 493
# ✅ Page 493 done. Movies collected: 9082
#
# 🔄 Language pt | Page 494
# ✅ Page 494 done. Movies collected: 9101
#
# 🔄 Language pt | Page 495
# ✅ Page 495 done. Movies collected: 9120
#
# 🔄 Language pt | Page 496
# ✅ Page 496 done. Movies collected: 9137
#
# 🔄 Language pt | Page 497
# ✅ Page 497 done. Movies collected: 9157
#
# 🔄 Language pt | Page 498
# ✅ Page 498 done. Movies collected: 9174
#
# 🔄 Language pt | Page 499
# ✅ Page 499 done. Movies collected: 9191
#
# 🔄 Language pt | Page 500
# ✅ Page 500 done. Movies collected: 9210
#
# 🎉 Done! Added 79822 new movies. Total now: 89147

# %%
import pandas as pd

# Load your scraped data
df = pd.read_csv("tmdb_movies.csv")

print(f"Original dataset size: {df.shape[0]} rows")

# 1. 🔁 Drop duplicate movies by Title (or use 'ID' if you have it)
df.drop_duplicates(subset="Title", inplace=True)

# 2. 🧹 Remove rows with any missing (NaN) values
df.dropna(inplace=True)

# 3. 🚫 Remove rows where critical fields are empty strings (e.g., Overview, Genre, Title)
columns_to_check = ["Title", "Overview", "Genres"]  # Add more columns if needed
for col in columns_to_check:
    df = df[df[col].str.strip() != ""]

# 4. 🔄 Reset index after drops
df.reset_index(drop=True, inplace=True)

# 5. 💾 Save cleaned version
df.to_csv("tmdb_movies_cleanedd.csv", index=False)

print(f"✅ Cleaned dataset saved as 'tmdb_movies_cleaned.csv'")
print(f"New dataset size: {df.shape[0]} rows")
# Out:
# Original dataset size: 89147 rows
# ✅ Cleaned dataset saved as 'tmdb_movies_cleaned.csv'
# New dataset size: 70747 rows
